# %%
from tool.s3_connect import S3_connector as s3
import pandas as pd

# %%
obj = s3()
s = obj.data_loader()

# %%
dir(s)
# Out:
# ['_PY_TO_OP_NAME',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cache',
#  '_client_config',
#  '_convert_to_request_dict',
#  '_emit_api_params',
#  '_endpoint',
#  '_exceptions',
#  '_exceptions_factory',
#  '_get_waiter_config',
#  '_load_exceptions',
#  '_loader',
#  '_make_api_call',
#  '_make_request',
#  '_register_handlers',
#  '_request_signer',
#  '_response_parser',
#  '_serializer',
#  '_service_model',
#  'abort_multipart_upload',
#  'can_paginate',
#  'complete_multipart_upload',
#  'copy',
#  'copy_object',
#  'create_bucket',
#  'create_multipart_upload',
#  'delete_bucket',
# ...

# %%
bucket = obj.get_bucket()

# %%
o = s.get_object(Bucket='newsdesk-raw', Key='경제/2020-10-30.csv')
df = pd.read_csv(o['Body'])

# %%
df
# Out:
#                  news_id                                            content
# 0     101-277-0004783157  아시아경제 산업통상자원부 장관 성윤모 와 한국석유화학협회는 30일 서울 롯데호텔에서...
# 1     101-008-0004492788  머니투데이 스마젠은 30일 권경훈 회장이 경북 바이오 산업단지를 찾은 정세균 국무총...
# 2     101-052-0001508437  농림축산식품부가 네덜란드에서 고병원성 조류인플루엔자 AI가 발생했다면서 네덜란드산 ...
# 3     101-052-0001508439  앵커 정부가 코로나 19 확산으로 잠정 중단했던 여행·외식 할인권을 오늘 30일 부...
# 4     101-018-0004773878  서부발전 여성CEO 사회안전망 구축에 5천만원 쾌척 한국여성경제인협회는 30일 한국...
# ...                  ...                                                ...
# 5655  101-469-0000549182  코로나 막는 나노세라믹 항균 필름 DI 쉐어켐 대표 김용주 은 첨단 나노소재 기술을...
# 5656  101-421-0004960150  평양 노동신문 뉴스1 북한 노동당 기관지 노동신문은 30일 당 제8차 대회를 향한 ...
# 5657  101-018-0004773014  이용우 의원 보험업감독규정 법령해석 의뢰 위임근거 없어 취득원가 로 지분보유 무효 ...
# 5658  101-366-0000611458  세계 최대의 증시 관련 지수 산출 기관인 모건스탠리캐피털인터내셔널 MSCI 의 11...
# 5659  101-366-0000611459  2024년 출시 ‘아이오닉7’용 배터리 공급 사업 코나 전기차 화재에 ‘탈LG’ 대...
#
# [5660 rows x 2 columns]

# %%
for k in bucket.object_versions.filter(Prefix='경제').all():
    print(k._object_key)
# Out:
# 경제/2020-10-30.csv
# 경제/2020-10-31.csv
# 경제/2020-11-01.csv
# 경제/2020-11-02.csv
# 경제/2020-11-03.csv
# 경제/2020-11-04.csv
# 경제/2020-11-05.csv
# 경제/2020-11-06.csv
# 경제/2020-11-07.csv
# 경제/2020-11-08.csv
# 경제/2020-11-09.csv
# 경제/2020-11-10.csv
# 경제/2020-11-11.csv
# 경제/2020-11-12.csv
# 경제/2020-11-13.csv
# 경제/2020-11-14.csv
# 경제/2020-11-15.csv
# 경제/2020-11-16.csv
# 경제/2020-11-17.csv
# 경제/2020-11-18.csv
# 경제/2020-11-19.csv
# 경제/2020-11-20.csv
# 경제/2020-11-21.csv
# 경제/2020-11-22.csv
