# %%
import pandas as pd
from tqdm import tqdm
import numpy as np
from konlpy.tag import Mecab
from gensim.models import Word2Vec
from scipy.spatial import distance
from sklearn.metrics.pairwise import cosine_similarity
import kss
import re
import networkx as nx
import warnings
warnings.filterwarnings("ignore")

# %%
#Mecab 객체 생성
mecab = Mecab()

# %%
# df 불러오기
df = pd.read_csv("./test.csv", header=None)
df.columns = ['article']

# %%
df = df.iloc[0:30]

# %%
# 중복 제거
df = df.drop_duplicates('article')
df.reset_index(inplace=True,drop=True)

# %%
df
# Out:
#                                               article
# 0   영국 옥스퍼드대 신종 코로나바이러스 감염증 코로나19 백신 연구. © 로이터 뉴스1...
# 1   크리스탈지노믹스가 수술이 힘든 진행성췌장암 환자에게 아이발티노스타트와 젬시타빈 얼로...
# 2   제주시는 최근 “신산공원 내 저류지를 개방해 반려동물 자율쉼터를 운영겠다”고 했다....
# 3   5월엔 43.1 서울경제 미국 공급관리협회 ISM 는 1일 현지시간 6월 제조업 구...
# 4   서울경제 극자외선용 EUV 포토레지스트를 생산하는 일본 기업 TOK가 국내에서 생산...
# 5   6·17 부동산 대책 내용에 반발하는 회원들이 만든 인터넷 카페가 포털 사이트에 항...
# 6   한독과 대한약사회가 지난 1일 서울 서초구 대한약사회관에서 제49회 약연상 시상식을...
# 7   요양보호사 광주 46번서 요양시설·교회로 전파…12명 추가 감염 서울 관악구서만 7...
# 8   아시아경제 뉴욕 백종민 특파원 미국 공급관리협회 ISM 는 1일 현지시간 6월 제조...
# 9   한국관광공사와 중국 최대 여행사인 트립닷컴이 1일 함께 진행한 한국 여행 상품 판매...
# 10  금감원 2018년 11월 이후 투자자 전액 배상 결정 금융투자상품 분쟁조정 사상 첫...
# 11  롯데마트와 홈플러스도 침방울 차단 마스크 판매 본격화 대부분 편의점에서도 살 수 있...
# 12  미국 월스트리트. © AFP 뉴스1 서울 뉴스1 한상희 기자 1일 현지시간 뉴욕증시...
# 13  24명 대상 임상실험서 긍정적 성과 3만명 대상 추가 실험 예정 연말까지 1억회분 ...
# 14  누적 사전등록자 수에 따라 추가 보상 지급 서울 뉴시스 이재은 기자 넷마블은 모바일...
# 15  머니투데이 문병환 기자 머니투데이와 공연 문화허브 M터치 가 펼치는 4대 가요제 중...
# 16  개발 중인 코로나 백신. © 로이터 뉴스1 서울 뉴스1 김정한 기자 독일 바이오기업...
# 17  리세 AP 뉴시스 네덜란드 리세에서 12일 현지시간 코로나19로 도로통행이 차단된 ...
# 18  스포츠경향 정세균 국무총리와 노사정 대표들이 1일 오전 10시30분 ‘코로나19 위...
# 19  뉴욕 연합뉴스 오진우 연합인포맥스 특파원 뉴욕증시에서 주요 지수는 1일 양호한 미국...
# 20  머니투데이 김소연 기자 도암엔지니어링이 회계처리 기준 위반으로 임원 해임권고 감사인...
# 21  머니투데이 김소연 기자 세화아이엠씨와 아이톡시가 공시위반으로 과징금 등의 조치를 받...
# 22  코로나19거 전 세계로 확산되는 가운데 미국 뉴욕 맨하탄 웨스트빌리지 7번가 한산한...
# 23  앵커 정부가 6·17 부동산 대책을 내놓은 지 보름가량 됐습니다. 추가 규제를 피한...
# 24  6월 서울 주택 매매가 석달 만에 상승 경기는 0.68% 뛰어 ‘풍선효과’ 뚜렷 아...
# 25  김소영 한국과학기술원 KAIST 과학기술정책대학원 교수 사진 가 사용후핵연료 관리정...
# 26  홍콩보안법 심각한 인권침해…일국양제 위반 중국이 홍콩 더 이상 특별하지 않게 만들어...
# 27  스포츠경향 국토교통부. 연합뉴스 6·17 부동산 대책 내용에 반발해 만들어진 인터넷...
# 28  HSBC 은행. © AFP 뉴스1 서울 뉴스1 김정한 기자 도미니크 라브 영국 외무...

# %%
# kss 모듈(문장분리기)로 문장화
df['sentence'] = [df['article'][i].split(". ") for i in range(len(df))]

# %%
df['sentence'][1]
# Out:
# ['크리스탈지노믹스가 수술이 힘든 진행성췌장암 환자에게 아이발티노스타트와 젬시타빈 얼로티닙3제병용요법의 1 2상 임상 시험 결과를 온라인으로 진행한 유럽종양학회 소화기암 국제회의에서 발표했습니다',
#  '임상시험은 수술이 불가능한 진행성 또는 전이성 췌장암환자 34명을 대상으로 진행했습니다',
#  '크리스탈지노믹스의 분자표적항암제 후보물질인 아이발티노스타트와 젬시타빈 얼로티닙3제 병용요법에 대해 임상 1상에서 최대내약용량을 구한 후 임상 2상에서 유효성을 평가한 결과 질병통제율 93.8% 객관적반응률 25% 전체생존기간 중간값 8.6개월 무진행 생존기간 중간값 5.3개월로 나타냈습니다',
#  '이번 임상시험 진행과 발표는 연대의대 세브란스병원 송시영 교수팀이 맡았습니다',
#  '송 교수는 현재 제한된 적은 수의 환자를 대상으로 한 2상 임상시험까지의 결과이지만 나름 우수한 약효를 보이고 있어서 향후 진행할 임상 3상 시험이 기대된다 고 말했습니다',
#  '한편 크리스탈지노믹스의 분자표적항암제인 아이발티노스타트는 지난해 8월 미국 식품의약국으로부터 희귀의약품으로 지정된 바 있습니다',
#  '크리스탈지노믹스 관계자는 이번 임상시험을 통해 아이발티노스타트의 안전성 및 유효성이 확인돼 수술이 불가능한 진행성 또는 전이성 췌장암환자들에게 새로운 치료제로가능성을 보일 것으로 기대한다 고 전했습니다.']

# %%
#각 문장의 길이가 20 이하인건 삭제
for i in range(len(df)):  
    for j in range(len(df['sentence'][i])-1,-1,-1):
        if len(df['sentence'][i][j]) <= 20:
            df['sentence'][i].remove(df['sentence'][i][j])

# %%
help(model)
# Out:
# ----------------------------------------------
# NameError    Traceback (most recent call last)
# <ipython-input-14-401d7c153909> in <module>
# ----> 1 help(model)
#
# NameError: name 'model' is not defined

# %%
#문장 전체 길이가 10 이하는 제거(기사를 제거)
df = df[df['sentence'].apply(lambda x: len(x) >= 10)]

# %%
df.reset_index(inplace=True,drop=True)

# %%
#stopwords list화
temp = pd.read_csv("/workspace/tool/stop_words.csv",header = None, usecols = [0], names = ['stopwords'])                                                
stopwords = [temp['stopwords'][i] for i in range(len(temp))]

# %%
#Mecab을 활용한 tokenize 및 불용어 제거
result = []
for i in range(len(df)):
    token_list = []
    for sentence in df['sentence'][i]:
        sentence = re.sub('[-=+,#/\?©:^$©@*\"※~&·%｜!』\\‘◇”|\(\)\[\]\<\>`\'’“…》]', '', sentence)
        tokenized = mecab.morphs(sentence)
        for j in range(len(tokenized)-1,-1,-1):
            if tokenized[j] in stopwords:
                tokenized.remove(tokenized[j])
        token_list.append(tokenized)
    result.append(token_list)
df['token'] = result

# %%
df
# Out:
#                                              article  \
# 0  요양보호사 광주 46번서 요양시설·교회로 전파…12명 추가 감염 서울 관악구서만 7...
# 1  한국관광공사와 중국 최대 여행사인 트립닷컴이 1일 함께 진행한 한국 여행 상품 판매...
# 2  금감원 2018년 11월 이후 투자자 전액 배상 결정 금융투자상품 분쟁조정 사상 첫...
# 3  롯데마트와 홈플러스도 침방울 차단 마스크 판매 본격화 대부분 편의점에서도 살 수 있...
# 4  머니투데이 문병환 기자 머니투데이와 공연 문화허브 M터치 가 펼치는 4대 가요제 중...
# 5  스포츠경향 정세균 국무총리와 노사정 대표들이 1일 오전 10시30분 ‘코로나19 위...
# 6  뉴욕 연합뉴스 오진우 연합인포맥스 특파원 뉴욕증시에서 주요 지수는 1일 양호한 미국...
# 7  코로나19거 전 세계로 확산되는 가운데 미국 뉴욕 맨하탄 웨스트빌리지 7번가 한산한...
# 8  앵커 정부가 6·17 부동산 대책을 내놓은 지 보름가량 됐습니다. 추가 규제를 피한...
# 9  6월 서울 주택 매매가 석달 만에 상승 경기는 0.68% 뛰어 ‘풍선효과’ 뚜렷 아...
#
#                                             sentence  \
# 0  [요양보호사 광주 46번서 요양시설·교회로 전파…12명 추가 감염 서울 관악구서만 ...
# 1  [한국관광공사와 중국 최대 여행사인 트립닷컴이 1일 함께 진행한 한국 여행 상품 판...
# 2  [금감원 2018년 11월 이후 투자자 전액 배상 결정 금융투자상품 분쟁조정 사상 ...
# 3  [롯데마트와 홈플러스도 침방울 차단 마스크 판매 본격화 대부분 편의점에서도 살 수 ...
# 4  [머니투데이 문병환 기자 머니투데이와 공연 문화허브 M터치 가 펼치는 4대 가요, ...
# 5  [스포츠경향 정세균 국무총리와 노사정 대표들이 1일 오전 10시30분 ‘코로나19 ...
# 6  [뉴욕 연합뉴스 오진우 연합인포맥스 특파원 뉴욕증시에서 주요 지수는 1일 양호한 미...
# 7  [코로나19거 전 세계로 확산되는 가운데 미국 뉴욕 맨하탄 웨스트빌리지 7번가 한산...
# 8  [앵커 정부가 6·17 부동산 대책을 내놓은 지 보름가량 됐습니다., 추가 규제를 ...
# 9  [6월 서울 주택 매매가 석달 만에 상승 경기는 0.68% 뛰어 ‘풍선효과’ 뚜렷 ...
#
#                                                token
# 0  [[요양, 보호사, 광주, 46, 번, 서, 요양, 시설, 교회, 전파, 12, 명...
# 1  [[한국, 관광공사, 중국, 최대, 여행사, 인, 트립, 닷컴, 1, 진행, 한, ...
# 2  [[금감원, 2018, 11, 이후, 투자자, 전액, 배상, 결정, 금융, 투자, ...
# 3  [[롯데마트, 홈플러스, 도, 침방울, 차단, 마스크, 판매, 본격, 화, 대부분,...
# 4  [[머니, 투데이, 문, 병환, 기자, 머니, 투데이, 공연, 문화, 허브, M, ...
# 5  [[스포츠, 경향, 정세균, 국무총리, 노사정, 대표, 1, 오전, 10, 시, 3...
# 6  [[뉴욕, 연합뉴스, 오진우, 연합, 인포, 맥스, 특파원, 뉴욕, 증시, 주요, ...
# 7  [[코로나, 19, 거, 전, 세계, 확산, 되, 는, 가운데, 미국, 뉴욕, 맨하...
# 8  [[앵커, 정부, 617, 부동산, 대책, 내놓, 은, 지, 보름, 가량, 됐, ....
# 9  [[6, 서울, 주택, 매매, 석, 달, 만, 상승, 경기, 는, 0, ., 68,...

# %%
mecab

# %%
# Word2Vec 모델링
# news_tokens = df['token'].tolist()  # data input as list

# params
v_dimension = 300
v_window = 8
model = Word2Vec.load('word2vec.model')

# model = Word2Vec(sentences = news_tokens, size = v_dimension, window = v_window, min_count = 5, workers = 4, sg = 0)

# %%
new_sentences = [['yes', 'this', 'is', 'the', 'word2vec', 'model', 'if',"you", "유승수","have","think","about","it",'yes', 'this', 'is', 'the', 'word2vec', 'model', 'if',"you", "유승수","have","think","about","it",'yes', 'this', 'is', 'the', 'word2vec', 'model', 'if',"you", "유승수","have","think","about","it",'yes', 'this', 'is', 'the', 'word2vec', 'model', 'if',"you", "유승수","have","think","about","it"]\
,['if',"you", "유승수","have","think","about","it",'if',"you", "유승수","have","think","about","it",'if',"you", "유승수","have","think","about","it",'if',"you", "유승수","have","think","about","it",'if',"you", "유승수","have","think","about","it",'if',"you", "유승수","have","think","about","it",'if',"you", "유승수","have","think","about","it",'if',"you", "유승수","have","think","about","it",'if',"you", "유승수","have","think","about","it",'if',"you", "유승수","have","think","about","it",'if',"you", "유승수","have","think","about","it",'if',"you", "유승수","have","think","about","it"]]
model.build_vocab(new_sentences, update = True)
model.train(new_sentences, total_examples=len(new_sentences), epochs = 10)
model.wv.vocab
# Out:
# {'영국': <gensim.models.keyedvectors.Vocab at 0x7f0e813d8220>,
#  '옥스퍼드': <gensim.models.keyedvectors.Vocab at 0x7f0e813d8af0>,
#  '대': <gensim.models.keyedvectors.Vocab at 0x7f0e813d87f0>,
#  '신종': <gensim.models.keyedvectors.Vocab at 0x7f0e813d8f10>,
#  '코로나': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f130>,
#  '바이러스': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f280>,
#  '감염증': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f2e0>,
#  '19': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f340>,
#  '백신': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f3a0>,
#  '연구': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f400>,
#  '로이터': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f490>,
#  '뉴스': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f520>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f5b0>,
#  '서울': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f610>,
#  '기자': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f670>,
#  '전': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f6d0>,
#  '세계': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f730>,
#  '중': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f760>,
#  '가장': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f4c0>,
#  '앞선': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f7f0>,
#  '평가': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f820>,
#  '받': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f880>,
#  '는': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f8e0>,
#  '진이': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f940>,
#  '최종': <gensim.models.keyedvectors.Vocab at 0x7f0e8145f9a0>,
#  '임상': <gensim.models.keyedvectors.Vocab at 0x7f0e8145fa00>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x7f0e8145fac0>,
#  '상': <gensim.models.keyedvectors.Vocab at 0x7f0e8145fb80>,
#  '시험': <gensim.models.keyedvectors.Vocab at 0x7f0e8145fc40>,
#  '긍정': <gensim.models.keyedvectors.Vocab at 0x7f0e8145fca0>,
#  '적': <gensim.models.keyedvectors.Vocab at 0x7f0e8145fd00>,
#  '인': <gensim.models.keyedvectors.Vocab at 0x7f0e8145fd60>,
#  '결과': <gensim.models.keyedvectors.Vocab at 0x7f0e8145fa90>,
#  '얻': <gensim.models.keyedvectors.Vocab at 0x7f0e8145fdf0>,
#  '었': <gensim.models.keyedvectors.Vocab at 0x7f0e8145fb50>,
#  '다고': <gensim.models.keyedvectors.Vocab at 0x7f0e8145fe80>,
#  '현지': <gensim.models.keyedvectors.Vocab at 0x7f0e8145fc10>,
#  '밝혔': <gensim.models.keyedvectors.Vocab at 0x7f0e8145ff10>,
#  '다': <gensim.models.keyedvectors.Vocab at 0x7f0e8145ff70>,
#  '통신': <gensim.models.keyedvectors.Vocab at 0x7f0e8145ffd0>,
#  '따르': <gensim.models.keyedvectors.Vocab at 0x7f0e814620a0>,
#  '면': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab11fd0>,
#  '의대': <gensim.models.keyedvectors.Vocab at 0x7f0e7a591ac0>,
#  '교수': <gensim.models.keyedvectors.Vocab at 0x7f0e7a591be0>,
#  '이날': <gensim.models.keyedvectors.Vocab at 0x7f0e813d8b20>,
#  '의회': <gensim.models.keyedvectors.Vocab at 0x7f0e813d8940>,
#  '출석': <gensim.models.keyedvectors.Vocab at 0x7f0e813d8820>,
#  '진행': <gensim.models.keyedvectors.Vocab at 0x7f0e813d8be0>,
#  '상황': <gensim.models.keyedvectors.Vocab at 0x7f0e813d86a0>,
#  '대한': <gensim.models.keyedvectors.Vocab at 0x7f0e813d89d0>,
#  '질문': <gensim.models.keyedvectors.Vocab at 0x7f0e813d8580>,
#  '후보': <gensim.models.keyedvectors.Vocab at 0x7f0e813d8520>,
#  '물질': <gensim.models.keyedvectors.Vocab at 0x7f0e813d8d00>,
#  '적절': <gensim.models.keyedvectors.Vocab at 0x7f0e813d8430>,
#  '한': <gensim.models.keyedvectors.Vocab at 0x7f0e813d8d30>,
#  '종류': <gensim.models.keyedvectors.Vocab at 0x7f0e813d82e0>,
#  '면역': <gensim.models.keyedvectors.Vocab at 0x7f0e87c23e20>,
#  '반응': <gensim.models.keyedvectors.Vocab at 0x7f0e8e0f2520>,
#  '보였': <gensim.models.keyedvectors.Vocab at 0x7f0e81462070>,
#  '고': <gensim.models.keyedvectors.Vocab at 0x7f0e81462130>,
#  '답': <gensim.models.keyedvectors.Vocab at 0x7f0e81462160>,
#  '했': <gensim.models.keyedvectors.Vocab at 0x7f0e81462190>,
#  '제약사': <gensim.models.keyedvectors.Vocab at 0x7f0e81462220>,
#  '네': <gensim.models.keyedvectors.Vocab at 0x7f0e81462280>,
#  '카': <gensim.models.keyedvectors.Vocab at 0x7f0e814622e0>,
#  '인체': <gensim.models.keyedvectors.Vocab at 0x7f0e81462340>,
#  '해': <gensim.models.keyedvectors.Vocab at 0x7f0e814623a0>,
#  '없': <gensim.models.keyedvectors.Vocab at 0x7f0e81462400>,
#  '유전자': <gensim.models.keyedvectors.Vocab at 0x7f0e81462460>,
#  '끼워': <gensim.models.keyedvectors.Vocab at 0x7f0e814624c0>,
#  '넣': <gensim.models.keyedvectors.Vocab at 0x7f0e81462520>,
#  '은': <gensim.models.keyedvectors.Vocab at 0x7f0e81462580>,
#  '개발': <gensim.models.keyedvectors.Vocab at 0x7f0e814625e0>,
#  '이달': <gensim.models.keyedvectors.Vocab at 0x7f0e81462640>,
#  '8000': <gensim.models.keyedvectors.Vocab at 0x7f0e814626a0>,
#  '명': <gensim.models.keyedvectors.Vocab at 0x7f0e81462700>,
#  '임상시험': <gensim.models.keyedvectors.Vocab at 0x7f0e81462760>,
#  '대상': <gensim.models.keyedvectors.Vocab at 0x7f0e814627c0>,
#  '으로': <gensim.models.keyedvectors.Vocab at 0x7f0e81462820>,
#  '있': <gensim.models.keyedvectors.Vocab at 0x7f0e81462880>,
#  '앞서': <gensim.models.keyedvectors.Vocab at 0x7f0e814628e0>,
#  '보건': <gensim.models.keyedvectors.Vocab at 0x7f0e81462940>,
#  '기구': <gensim.models.keyedvectors.Vocab at 0x7f0e814629a0>,
#  'WHO': <gensim.models.keyedvectors.Vocab at 0x7f0e81462a00>,
#  '제네': <gensim.models.keyedvectors.Vocab at 0x7f0e81462a60>,
#  '하': <gensim.models.keyedvectors.Vocab at 0x7f0e81462ac0>,
#  '기': <gensim.models.keyedvectors.Vocab at 0x7f0e81462b20>,
#  '도': <gensim.models.keyedvectors.Vocab at 0x7f0e81462b80>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x7f0e81462be0>,
#  '말': <gensim.models.keyedvectors.Vocab at 0x7f0e81462c40>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x7f0e81462ca0>,
#  '까지': <gensim.models.keyedvectors.Vocab at 0x7f0e81462d00>,
#  '100': <gensim.models.keyedvectors.Vocab at 0x7f0e81462d60>,
#  '만': <gensim.models.keyedvectors.Vocab at 0x7f0e81462dc0>,
#  '회분': <gensim.models.keyedvectors.Vocab at 0x7f0e81462e20>,
#  '생산': <gensim.models.keyedvectors.Vocab at 0x7f0e81462e80>,
#  '계획': <gensim.models.keyedvectors.Vocab at 0x7f0e81462ee0>,
#  '언제': <gensim.models.keyedvectors.Vocab at 0x7f0e81462f40>,
#  '준비': <gensim.models.keyedvectors.Vocab at 0x7f0e81462fa0>,
#  '될': <gensim.models.keyedvectors.Vocab at 0x7f0e81236040>,
#  '지': <gensim.models.keyedvectors.Vocab at 0x7f0e812360a0>,
#  '따라': <gensim.models.keyedvectors.Vocab at 0x7f0e81236100>,
#  '달려': <gensim.models.keyedvectors.Vocab at 0x7f0e81236160>,
#  '며': <gensim.models.keyedvectors.Vocab at 0x7f0e812361c0>,
#  '지금': <gensim.models.keyedvectors.Vocab at 0x7f0e81236220>,
#  '시점': <gensim.models.keyedvectors.Vocab at 0x7f0e81236280>,
#  '제시': <gensim.models.keyedvectors.Vocab at 0x7f0e812362e0>,
#  '할': <gensim.models.keyedvectors.Vocab at 0x7f0e81236340>,
#  '순': <gensim.models.keyedvectors.Vocab at 0x7f0e812363a0>,
#  '신중': <gensim.models.keyedvectors.Vocab at 0x7f0e81236400>,
#  '태도': <gensim.models.keyedvectors.Vocab at 0x7f0e81236460>,
#  '크리스탈': <gensim.models.keyedvectors.Vocab at 0x7f0e812364c0>,
#  '지노': <gensim.models.keyedvectors.Vocab at 0x7f0e81236520>,
#  '믹스': <gensim.models.keyedvectors.Vocab at 0x7f0e81236580>,
#  '수술': <gensim.models.keyedvectors.Vocab at 0x7f0e812365e0>,
#  '힘든': <gensim.models.keyedvectors.Vocab at 0x7f0e81236640>,
#  '성': <gensim.models.keyedvectors.Vocab at 0x7f0e812366a0>,
#  '췌장암': <gensim.models.keyedvectors.Vocab at 0x7f0e81236700>,
#  '환자': <gensim.models.keyedvectors.Vocab at 0x7f0e81236760>,
#  '발티노스': <gensim.models.keyedvectors.Vocab at 0x7f0e812367c0>,
#  '타트': <gensim.models.keyedvectors.Vocab at 0x7f0e81236820>,
#  '젬': <gensim.models.keyedvectors.Vocab at 0x7f0e81236880>,
#  '시': <gensim.models.keyedvectors.Vocab at 0x7f0e812368e0>,
#  '타빈': <gensim.models.keyedvectors.Vocab at 0x7f0e81236940>,
#  '얼': <gensim.models.keyedvectors.Vocab at 0x7f0e812369a0>,
#  '로티': <gensim.models.keyedvectors.Vocab at 0x7f0e81236a00>,
#  '닙': <gensim.models.keyedvectors.Vocab at 0x7f0e81236a60>,
#  '용': <gensim.models.keyedvectors.Vocab at 0x7f0e81236ac0>,
#  '요법': <gensim.models.keyedvectors.Vocab at 0x7f0e81236b20>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x7f0e81236b80>,
#  '온라인': <gensim.models.keyedvectors.Vocab at 0x7f0e81236be0>,
#  '유럽': <gensim.models.keyedvectors.Vocab at 0x7f0e81236c40>,
#  '종양': <gensim.models.keyedvectors.Vocab at 0x7f0e81236ca0>,
#  '학회': <gensim.models.keyedvectors.Vocab at 0x7f0e81236d00>,
#  '소화': <gensim.models.keyedvectors.Vocab at 0x7f0e81236d60>,
#  '기암': <gensim.models.keyedvectors.Vocab at 0x7f0e81236dc0>,
#  '국제': <gensim.models.keyedvectors.Vocab at 0x7f0e81236e20>,
#  '회의': <gensim.models.keyedvectors.Vocab at 0x7f0e81236e80>,
#  '발표': <gensim.models.keyedvectors.Vocab at 0x7f0e81236ee0>,
#  '불': <gensim.models.keyedvectors.Vocab at 0x7f0e81236f40>,
#  '가능': <gensim.models.keyedvectors.Vocab at 0x7f0e81236fa0>,
#  '또는': <gensim.models.keyedvectors.Vocab at 0x7f0e81120040>,
#  '전이': <gensim.models.keyedvectors.Vocab at 0x7f0e811200a0>,
#  '34': <gensim.models.keyedvectors.Vocab at 0x7f0e81120100>,
#  '분자': <gensim.models.keyedvectors.Vocab at 0x7f0e81120160>,
#  '표적': <gensim.models.keyedvectors.Vocab at 0x7f0e811201c0>,
#  '항암제': <gensim.models.keyedvectors.Vocab at 0x7f0e81120220>,
#  '병': <gensim.models.keyedvectors.Vocab at 0x7f0e81120280>,
#  '대해': <gensim.models.keyedvectors.Vocab at 0x7f0e811202e0>,
#  '최대': <gensim.models.keyedvectors.Vocab at 0x7f0e81120340>,
#  '내': <gensim.models.keyedvectors.Vocab at 0x7f0e811203a0>,
#  '약용량': <gensim.models.keyedvectors.Vocab at 0x7f0e81120400>,
#  '구한': <gensim.models.keyedvectors.Vocab at 0x7f0e81120460>,
#  '후': <gensim.models.keyedvectors.Vocab at 0x7f0e811204c0>,
#  '유효': <gensim.models.keyedvectors.Vocab at 0x7f0e81120520>,
#  '질병': <gensim.models.keyedvectors.Vocab at 0x7f0e81120580>,
#  '통제': <gensim.models.keyedvectors.Vocab at 0x7f0e811205e0>,
#  '율': <gensim.models.keyedvectors.Vocab at 0x7f0e81120640>,
#  '938': <gensim.models.keyedvectors.Vocab at 0x7f0e811206a0>,
#  '객관': <gensim.models.keyedvectors.Vocab at 0x7f0e81120700>,
#  '률': <gensim.models.keyedvectors.Vocab at 0x7f0e81120760>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x7f0e811207c0>,
#  '전체': <gensim.models.keyedvectors.Vocab at 0x7f0e81120820>,
#  '생존': <gensim.models.keyedvectors.Vocab at 0x7f0e81120880>,
#  '기간': <gensim.models.keyedvectors.Vocab at 0x7f0e811208e0>,
#  '중간값': <gensim.models.keyedvectors.Vocab at 0x7f0e81120940>,
#  '86': <gensim.models.keyedvectors.Vocab at 0x7f0e811209a0>,
#  '개월': <gensim.models.keyedvectors.Vocab at 0x7f0e81120a00>,
#  '무': <gensim.models.keyedvectors.Vocab at 0x7f0e81120a60>,
#  '53': <gensim.models.keyedvectors.Vocab at 0x7f0e81120ac0>,
#  '나타냈': <gensim.models.keyedvectors.Vocab at 0x7f0e81120b20>,
#  '연대': <gensim.models.keyedvectors.Vocab at 0x7f0e81120b80>,
#  '세브': <gensim.models.keyedvectors.Vocab at 0x7f0e81120be0>,
#  '란스': <gensim.models.keyedvectors.Vocab at 0x7f0e81120c40>,
#  '병원': <gensim.models.keyedvectors.Vocab at 0x7f0e81120ca0>,
#  '송시영': <gensim.models.keyedvectors.Vocab at 0x7f0e81120d00>,
#  '팀': <gensim.models.keyedvectors.Vocab at 0x7f0e81120d60>,
#  '맡': <gensim.models.keyedvectors.Vocab at 0x7f0e81120dc0>,
#  '았': <gensim.models.keyedvectors.Vocab at 0x7f0e81120e20>,
#  '송': <gensim.models.keyedvectors.Vocab at 0x7f0e81120e80>,
#  '현재': <gensim.models.keyedvectors.Vocab at 0x7f0e81120ee0>,
#  '제한': <gensim.models.keyedvectors.Vocab at 0x7f0e81120f40>,
#  '된': <gensim.models.keyedvectors.Vocab at 0x7f0e81120fa0>,
#  '수': <gensim.models.keyedvectors.Vocab at 0x7f0e81118040>,
#  '지만': <gensim.models.keyedvectors.Vocab at 0x7f0e811180a0>,
#  '나름': <gensim.models.keyedvectors.Vocab at 0x7f0e81118100>,
#  '우수': <gensim.models.keyedvectors.Vocab at 0x7f0e81118160>,
#  '약효': <gensim.models.keyedvectors.Vocab at 0x7f0e811181c0>,
#  '보이': <gensim.models.keyedvectors.Vocab at 0x7f0e81118220>,
#  '어서': <gensim.models.keyedvectors.Vocab at 0x7f0e81118280>,
#  '향후': <gensim.models.keyedvectors.Vocab at 0x7f0e811182e0>,
#  '기대': <gensim.models.keyedvectors.Vocab at 0x7f0e81118340>,
#  '된다': <gensim.models.keyedvectors.Vocab at 0x7f0e811183a0>,
#  '한편': <gensim.models.keyedvectors.Vocab at 0x7f0e81118400>,
#  '지난해': <gensim.models.keyedvectors.Vocab at 0x7f0e81118460>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x7f0e811184c0>,
#  '미국': <gensim.models.keyedvectors.Vocab at 0x7f0e81118520>,
#  '식품': <gensim.models.keyedvectors.Vocab at 0x7f0e81118580>,
#  '약국': <gensim.models.keyedvectors.Vocab at 0x7f0e811185e0>,
#  '으로부터': <gensim.models.keyedvectors.Vocab at 0x7f0e81118640>,
#  '희귀': <gensim.models.keyedvectors.Vocab at 0x7f0e811186a0>,
#  '의약품': <gensim.models.keyedvectors.Vocab at 0x7f0e81118700>,
#  '지정': <gensim.models.keyedvectors.Vocab at 0x7f0e81118760>,
#  '바': <gensim.models.keyedvectors.Vocab at 0x7f0e811187c0>,
#  '관계자': <gensim.models.keyedvectors.Vocab at 0x7f0e81118820>,
#  '이번': <gensim.models.keyedvectors.Vocab at 0x7f0e81118880>,
#  '통해': <gensim.models.keyedvectors.Vocab at 0x7f0e811188e0>,
#  '아이': <gensim.models.keyedvectors.Vocab at 0x7f0e81118940>,
#  '의': <gensim.models.keyedvectors.Vocab at 0x7f0e811189a0>,
#  '안전': <gensim.models.keyedvectors.Vocab at 0x7f0e81118a00>,
#  '확인': <gensim.models.keyedvectors.Vocab at 0x7f0e81118a60>,
#  '돼': <gensim.models.keyedvectors.Vocab at 0x7f0e81118ac0>,
#  '에게': <gensim.models.keyedvectors.Vocab at 0x7f0e81118b20>,
#  '새로운': <gensim.models.keyedvectors.Vocab at 0x7f0e81118b80>,
#  '치료제': <gensim.models.keyedvectors.Vocab at 0x7f0e81118be0>,
#  '보일': <gensim.models.keyedvectors.Vocab at 0x7f0e81118c40>,
#  '한다': <gensim.models.keyedvectors.Vocab at 0x7f0e81118ca0>,
#  '전했': <gensim.models.keyedvectors.Vocab at 0x7f0e81118d00>,
#  '제주': <gensim.models.keyedvectors.Vocab at 0x7f0e81118d60>,
#  '최근': <gensim.models.keyedvectors.Vocab at 0x7f0e81118dc0>,
#  '공원': <gensim.models.keyedvectors.Vocab at 0x7f0e81118e20>,
#  '저류지': <gensim.models.keyedvectors.Vocab at 0x7f0e81118e80>,
#  '개방': <gensim.models.keyedvectors.Vocab at 0x7f0e81118ee0>,
#  '반려': <gensim.models.keyedvectors.Vocab at 0x7f0e81118f40>,
#  '동물': <gensim.models.keyedvectors.Vocab at 0x7f0e81118fa0>,
#  '자율': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf040>,
#  '쉼터': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf0a0>,
#  '운영': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf100>,
#  '사진': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf160>,
#  '제공': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf1c0>,
#  '주시': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf220>,
#  '함께': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf280>,
#  '산책': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf2e0>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf340>,
#  '도시': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf3a0>,
#  '즐길': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf400>,
#  '비': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf460>,
#  '반': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf4c0>,
#  '소음': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf520>,
#  '배변': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf580>,
#  '인한': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf5e0>,
#  '피해': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf640>,
#  '최소': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf6a0>,
#  '화': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf700>,
#  '위해': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf760>,
#  '마련': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf7c0>,
#  '됐': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf820>,
#  '동': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf880>,
#  '면적': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf8e0>,
#  '390': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf940>,
#  '㎡': <gensim.models.keyedvectors.Vocab at 0x7f0e818cf9a0>,
#  '저감': <gensim.models.keyedvectors.Vocab at 0x7f0e818cfa00>,
#  '종합': <gensim.models.keyedvectors.Vocab at 0x7f0e818cfa60>,
#  '태풍': <gensim.models.keyedvectors.Vocab at 0x7f0e818cfac0>,
#  '자연재해': <gensim.models.keyedvectors.Vocab at 0x7f0e818cfb20>,
#  '대비': <gensim.models.keyedvectors.Vocab at 0x7f0e818cfb80>,
#  '조성': <gensim.models.keyedvectors.Vocab at 0x7f0e818cfbe0>,
#  '이용자': <gensim.models.keyedvectors.Vocab at 0x7f0e818cfc40>,
#  '접근성': <gensim.models.keyedvectors.Vocab at 0x7f0e818cfca0>,
#  '용이': <gensim.models.keyedvectors.Vocab at 0x7f0e818cfd00>,
#  '지대': <gensim.models.keyedvectors.Vocab at 0x7f0e818cfd60>,
#  '낮': <gensim.models.keyedvectors.Vocab at 0x7f0e818cfdc0>,
#  '탈출': <gensim.models.keyedvectors.Vocab at 0x7f0e818cfe20>,
#  '위협': <gensim.models.keyedvectors.Vocab at 0x7f0e818cfe80>,
#  '안전사고': <gensim.models.keyedvectors.Vocab at 0x7f0e818cfee0>,
#  '위험': <gensim.models.keyedvectors.Vocab at 0x7f0e818cff40>,
#  '것': <gensim.models.keyedvectors.Vocab at 0x7f0e818cffa0>,
#  '판단': <gensim.models.keyedvectors.Vocab at 0x7f0e81765040>,
#  '게': <gensim.models.keyedvectors.Vocab at 0x7f0e817650a0>,
#  '동반': <gensim.models.keyedvectors.Vocab at 0x7f0e81765100>,
#  '등록': <gensim.models.keyedvectors.Vocab at 0x7f0e81765160>,
#  '착용': <gensim.models.keyedvectors.Vocab at 0x7f0e817651c0>,
#  '지참': <gensim.models.keyedvectors.Vocab at 0x7f0e81765220>,
#  '무료': <gensim.models.keyedvectors.Vocab at 0x7f0e81765280>,
#  '이용': <gensim.models.keyedvectors.Vocab at 0x7f0e817652e0>,
#  '제주시': <gensim.models.keyedvectors.Vocab at 0x7f0e81765340>,
#  '금번': <gensim.models.keyedvectors.Vocab at 0x7f0e817653a0>,
#  '되': <gensim.models.keyedvectors.Vocab at 0x7f0e81765400>,
#  '놀이터': <gensim.models.keyedvectors.Vocab at 0x7f0e81765460>,
#  '사람': <gensim.models.keyedvectors.Vocab at 0x7f0e817654c0>,
#  '이': <gensim.models.keyedvectors.Vocab at 0x7f0e81765520>,
#  '행복': <gensim.models.keyedvectors.Vocab at 0x7f0e81765580>,
#  '만들': <gensim.models.keyedvectors.Vocab at 0x7f0e817655e0>,
#  '나가': <gensim.models.keyedvectors.Vocab at 0x7f0e81765640>,
#  '데': <gensim.models.keyedvectors.Vocab at 0x7f0e817656a0>,
#  '최선': <gensim.models.keyedvectors.Vocab at 0x7f0e81765700>,
#  '을': <gensim.models.keyedvectors.Vocab at 0x7f0e81765760>,
#  '겠': <gensim.models.keyedvectors.Vocab at 0x7f0e817657c0>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x7f0e81765820>,
#  '엔': <gensim.models.keyedvectors.Vocab at 0x7f0e81765880>,
#  '431': <gensim.models.keyedvectors.Vocab at 0x7f0e817658e0>,
#  '서울경제': <gensim.models.keyedvectors.Vocab at 0x7f0e81765940>,
#  '공급': <gensim.models.keyedvectors.Vocab at 0x7f0e817659a0>,
#  '관리': <gensim.models.keyedvectors.Vocab at 0x7f0e81765a00>,
#  '협회': <gensim.models.keyedvectors.Vocab at 0x7f0e81765a60>,
#  'ISM': <gensim.models.keyedvectors.Vocab at 0x7f0e81765ac0>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x7f0e81765b20>,
#  '제조업': <gensim.models.keyedvectors.Vocab at 0x7f0e81765b80>,
#  '구매': <gensim.models.keyedvectors.Vocab at 0x7f0e81765be0>,
#  '관리자': <gensim.models.keyedvectors.Vocab at 0x7f0e81765c40>,
#  '지수': <gensim.models.keyedvectors.Vocab at 0x7f0e81765ca0>,
#  'PMI': <gensim.models.keyedvectors.Vocab at 0x7f0e81765d00>,
#  '526': <gensim.models.keyedvectors.Vocab at 0x7f0e81765d60>,
#  '기록': <gensim.models.keyedvectors.Vocab at 0x7f0e81765dc0>,
#  '전문가': <gensim.models.keyedvectors.Vocab at 0x7f0e81765e20>,
#  '예상': <gensim.models.keyedvectors.Vocab at 0x7f0e81765e80>,
#  '치': <gensim.models.keyedvectors.Vocab at 0x7f0e81765ee0>,
#  '495': <gensim.models.keyedvectors.Vocab at 0x7f0e81765f40>,
#  '넘어선': <gensim.models.keyedvectors.Vocab at 0x7f0e81765fa0>,
#  '에': <gensim.models.keyedvectors.Vocab at 0x7f0e81319040>,
#  '사태': <gensim.models.keyedvectors.Vocab at 0x7f0e813190a0>,
#  '추락': <gensim.models.keyedvectors.Vocab at 0x7f0e81319100>,
#  '던': <gensim.models.keyedvectors.Vocab at 0x7f0e81319160>,
#  '경기': <gensim.models.keyedvectors.Vocab at 0x7f0e813191c0>,
#  '다시': <gensim.models.keyedvectors.Vocab at 0x7f0e81319220>,
#  '확장': <gensim.models.keyedvectors.Vocab at 0x7f0e81319280>,
#  '국면': <gensim.models.keyedvectors.Vocab at 0x7f0e813192e0>,
#  '진입': <gensim.models.keyedvectors.Vocab at 0x7f0e81319340>,
#  '다는': <gensim.models.keyedvectors.Vocab at 0x7f0e813193a0>,
#  '분석': <gensim.models.keyedvectors.Vocab at 0x7f0e81319400>,
#  '나온다': <gensim.models.keyedvectors.Vocab at 0x7f0e81319460>,
#  '50': <gensim.models.keyedvectors.Vocab at 0x7f0e813194c0>,
#  '넘어서': <gensim.models.keyedvectors.Vocab at 0x7f0e81319520>,
#  '축소': <gensim.models.keyedvectors.Vocab at 0x7f0e81319580>,
#  '의미': <gensim.models.keyedvectors.Vocab at 0x7f0e813195e0>,
#  '극자외선': <gensim.models.keyedvectors.Vocab at 0x7f0e81319640>,
#  'EUV': <gensim.models.keyedvectors.Vocab at 0x7f0e813196a0>,
#  '포토레지스트': <gensim.models.keyedvectors.Vocab at 0x7f0e81319700>,
#  '일본': <gensim.models.keyedvectors.Vocab at 0x7f0e81319760>,
#  '기업': <gensim.models.keyedvectors.Vocab at 0x7f0e813197c0>,
#  'TOK': <gensim.models.keyedvectors.Vocab at 0x7f0e81319820>,
#  '국내': <gensim.models.keyedvectors.Vocab at 0x7f0e81319880>,
#  '시작': <gensim.models.keyedvectors.Vocab at 0x7f0e813198e0>,
#  '알려졌': <gensim.models.keyedvectors.Vocab at 0x7f0e81319940>,
#  '정부': <gensim.models.keyedvectors.Vocab at 0x7f0e813199a0>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x7f0e81319a00>,
#  '부터': <gensim.models.keyedvectors.Vocab at 0x7f0e81319a60>,
#  '수출': <gensim.models.keyedvectors.Vocab at 0x7f0e81319ac0>,
#  '규제': <gensim.models.keyedvectors.Vocab at 0x7f0e81319b20>,
#  '품목': <gensim.models.keyedvectors.Vocab at 0x7f0e81319b80>,
#  '산업': <gensim.models.keyedvectors.Vocab at 0x7f0e81319be0>,
#  '통상': <gensim.models.keyedvectors.Vocab at 0x7f0e81319c40>,
#  '자원': <gensim.models.keyedvectors.Vocab at 0x7f0e81319ca0>,
#  '부': <gensim.models.keyedvectors.Vocab at 0x7f0e81319d00>,
#  '측': <gensim.models.keyedvectors.Vocab at 0x7f0e81319d60>,
#  '매체': <gensim.models.keyedvectors.Vocab at 0x7f0e81319dc0>,
#  '그룹': <gensim.models.keyedvectors.Vocab at 0x7f0e81319e20>,
#  '케이': <gensim.models.keyedvectors.Vocab at 0x7f0e81319e80>,
#  '첨단': <gensim.models.keyedvectors.Vocab at 0x7f0e81319ee0>,
#  '재료': <gensim.models.keyedvectors.Vocab at 0x7f0e81319f40>,
#  '주식회사': <gensim.models.keyedvectors.Vocab at 0x7f0e81319fa0>,
#  '인명': <gensim.models.keyedvectors.Vocab at 0x7f0e81522040>,
#  '제조': <gensim.models.keyedvectors.Vocab at 0x7f0e815220a0>,
#  '으며': <gensim.models.keyedvectors.Vocab at 0x7f0e81522100>,
#  '제품': <gensim.models.keyedvectors.Vocab at 0x7f0e81522160>,
#  '적시': <gensim.models.keyedvectors.Vocab at 0x7f0e815221c0>,
#  '내용': <gensim.models.keyedvectors.Vocab at 0x7f0e81522220>,
#  '서면': <gensim.models.keyedvectors.Vocab at 0x7f0e81522280>,
#  '보냈': <gensim.models.keyedvectors.Vocab at 0x7f0e815222e0>,
#  '한국': <gensim.models.keyedvectors.Vocab at 0x7f0e81522340>,
#  '법인': <gensim.models.keyedvectors.Vocab at 0x7f0e815223a0>,
#  '삼성전자': <gensim.models.keyedvectors.Vocab at 0x7f0e81522400>,
#  '반도체': <gensim.models.keyedvectors.Vocab at 0x7f0e81522460>,
#  '공정': <gensim.models.keyedvectors.Vocab at 0x7f0e815224c0>,
#  '적용': <gensim.models.keyedvectors.Vocab at 0x7f0e81522520>,
#  '테스트': <gensim.models.keyedvectors.Vocab at 0x7f0e81522580>,
#  '전해졌': <gensim.models.keyedvectors.Vocab at 0x7f0e815225e0>,
#  '메모리': <gensim.models.keyedvectors.Vocab at 0x7f0e81522640>,
#  '라인': <gensim.models.keyedvectors.Vocab at 0x7f0e815226a0>,
#  '사용': <gensim.models.keyedvectors.Vocab at 0x7f0e81522700>,
#  '소재': <gensim.models.keyedvectors.Vocab at 0x7f0e81522760>,
#  'SK': <gensim.models.keyedvectors.Vocab at 0x7f0e815227c0>,
#  '하이닉스': <gensim.models.keyedvectors.Vocab at 0x7f0e81522820>,
#  '경우': <gensim.models.keyedvectors.Vocab at 0x7f0e81522880>,
#  'D': <gensim.models.keyedvectors.Vocab at 0x7f0e815228e0>,
#  '램': <gensim.models.keyedvectors.Vocab at 0x7f0e81522940>,
#  '사업': <gensim.models.keyedvectors.Vocab at 0x7f0e815229a0>,
#  '주력': <gensim.models.keyedvectors.Vocab at 0x7f0e81522a00>,
#  '점': <gensim.models.keyedvectors.Vocab at 0x7f0e81522a60>,
#  '감안': <gensim.models.keyedvectors.Vocab at 0x7f0e81522ac0>,
#  '다면': <gensim.models.keyedvectors.Vocab at 0x7f0e81522b20>,
#  '관심': <gensim.models.keyedvectors.Vocab at 0x7f0e81522b80>,
#  '보인다': <gensim.models.keyedvectors.Vocab at 0x7f0e81522be0>,
#  '617': <gensim.models.keyedvectors.Vocab at 0x7f0e81522c40>,
#  '부동산': <gensim.models.keyedvectors.Vocab at 0x7f0e81522ca0>,
#  '대책': <gensim.models.keyedvectors.Vocab at 0x7f0e81522d00>,
#  '반발': <gensim.models.keyedvectors.Vocab at 0x7f0e81522d60>,
#  '회원': <gensim.models.keyedvectors.Vocab at 0x7f0e81522dc0>,
#  '만든': <gensim.models.keyedvectors.Vocab at 0x7f0e81522e20>,
#  '인터넷': <gensim.models.keyedvectors.Vocab at 0x7f0e81522e80>,
#  '카페': <gensim.models.keyedvectors.Vocab at 0x7f0e81522ee0>,
#  '포털': <gensim.models.keyedvectors.Vocab at 0x7f0e81522f40>,
#  '사이트': <gensim.models.keyedvectors.Vocab at 0x7f0e81522fa0>,
#  '항의성': <gensim.models.keyedvectors.Vocab at 0x7f0e81444040>,
#  '실시간': <gensim.models.keyedvectors.Vocab at 0x7f0e814440a0>,
#  '검색어': <gensim.models.keyedvectors.Vocab at 0x7f0e81444100>,
#  '올리': <gensim.models.keyedvectors.Vocab at 0x7f0e81444160>,
#  '오늘': <gensim.models.keyedvectors.Vocab at 0x7f0e814441c0>,
#  '오후': <gensim.models.keyedvectors.Vocab at 0x7f0e81444220>,
#  '네이버': <gensim.models.keyedvectors.Vocab at 0x7f0e81444280>,
#  '김현미': <gensim.models.keyedvectors.Vocab at 0x7f0e814442e0>,
#  '장관': <gensim.models.keyedvectors.Vocab at 0x7f0e81444340>,
#  '거짓말': <gensim.models.keyedvectors.Vocab at 0x7f0e814443a0>,
#  '라는': <gensim.models.keyedvectors.Vocab at 0x7f0e81444400>,
#  '단어': <gensim.models.keyedvectors.Vocab at 0x7f0e81444460>,
#  '상위': <gensim.models.keyedvectors.Vocab at 0x7f0e814444c0>,
#  '권': <gensim.models.keyedvectors.Vocab at 0x7f0e81444520>,
#  '올랐': <gensim.models.keyedvectors.Vocab at 0x7f0e81444580>,
#  '비판': <gensim.models.keyedvectors.Vocab at 0x7f0e814445e0>,
#  '집중': <gensim.models.keyedvectors.Vocab at 0x7f0e81444640>,
#  '검색': <gensim.models.keyedvectors.Vocab at 0x7f0e814446a0>,
#  '졌': <gensim.models.keyedvectors.Vocab at 0x7f0e81444700>,
#  '나오': <gensim.models.keyedvectors.Vocab at 0x7f0e81444760>,
#  '이전': <gensim.models.keyedvectors.Vocab at 0x7f0e814447c0>,
#  '아파트': <gensim.models.keyedvectors.Vocab at 0x7f0e81444820>,
#  '분양': <gensim.models.keyedvectors.Vocab at 0x7f0e81444880>,
#  '거주지': <gensim.models.keyedvectors.Vocab at 0x7f0e814448e0>,
#  '지역': <gensim.models.keyedvectors.Vocab at 0x7f0e81444940>,
#  '묶이': <gensim.models.keyedvectors.Vocab at 0x7f0e814449a0>,
#  '면서': <gensim.models.keyedvectors.Vocab at 0x7f0e81444a00>,
#  '주택': <gensim.models.keyedvectors.Vocab at 0x7f0e81444a60>,
#  '담보': <gensim.models.keyedvectors.Vocab at 0x7f0e81444ac0>,
#  '대출': <gensim.models.keyedvectors.Vocab at 0x7f0e81444b20>,
#  '비율': <gensim.models.keyedvectors.Vocab at 0x7f0e81444b80>,
#  '줄': <gensim.models.keyedvectors.Vocab at 0x7f0e81444be0>,
#  '소급': <gensim.models.keyedvectors.Vocab at 0x7f0e81444c40>,
#  '보': <gensim.models.keyedvectors.Vocab at 0x7f0e81444ca0>,
#  '호소': <gensim.models.keyedvectors.Vocab at 0x7f0e81444d00>,
#  '어제': <gensim.models.keyedvectors.Vocab at 0x7f0e81444d60>,
#  '위헌': <gensim.models.keyedvectors.Vocab at 0x7f0e81444dc0>,
#  '매일': <gensim.models.keyedvectors.Vocab at 0x7f0e81444e20>,
#  '운동': <gensim.models.keyedvectors.Vocab at 0x7f0e81444e80>,
#  '오프라인': <gensim.models.keyedvectors.Vocab at 0x7f0e81444ee0>,
#  '회견': <gensim.models.keyedvectors.Vocab at 0x7f0e81444f40>,
#  '본격': <gensim.models.keyedvectors.Vocab at 0x7f0e81444fa0>,
#  '집단': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6040>,
#  '행동': <gensim.models.keyedvectors.Vocab at 0x7f0e816b60a0>,
#  '예고': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6100>,
#  '지난달': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6160>,
#  '24': <gensim.models.keyedvectors.Vocab at 0x7f0e816b61c0>,
#  '진': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6220>,
#  '천': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6280>,
#  '넘어섰': <gensim.models.keyedvectors.Vocab at 0x7f0e816b62e0>,
#  '약사회': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6340>,
#  '지난': <gensim.models.keyedvectors.Vocab at 0x7f0e816b63a0>,
#  '서초구': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6400>,
#  '약사': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6460>,
#  '회관': <gensim.models.keyedvectors.Vocab at 0x7f0e816b64c0>,
#  '제': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6520>,
#  '49': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6580>,
#  '회': <gensim.models.keyedvectors.Vocab at 0x7f0e816b65e0>,
#  '시상식': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6640>,
#  '개최': <gensim.models.keyedvectors.Vocab at 0x7f0e816b66a0>,
#  '약': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6700>,
#  '연상': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6760>,
#  '평소': <gensim.models.keyedvectors.Vocab at 0x7f0e816b67c0>,
#  '윤리': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6820>,
#  '성실히': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6880>,
#  '이행': <gensim.models.keyedvectors.Vocab at 0x7f0e816b68e0>,
#  '국민': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6940>,
#  '향상': <gensim.models.keyedvectors.Vocab at 0x7f0e816b69a0>,
#  '사회': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6a00>,
#  '발전': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6a60>,
#  '헌신': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6ac0>,
#  '온': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6b20>,
#  '매년': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6b80>,
#  '수여': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6be0>,
#  '수상자': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6c40>,
#  '함': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6ca0>,
#  '섭': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6d00>,
#  '방': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6d60>,
#  '대유': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6dc0>,
#  '입니다': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6e20>,
#  '탑': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6e80>,
#  '500': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6ee0>,
#  '원': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6f40>,
#  '상금': <gensim.models.keyedvectors.Vocab at 0x7f0e816b6fa0>,
#  '각각': <gensim.models.keyedvectors.Vocab at 0x7f0e81845040>,
#  '요양': <gensim.models.keyedvectors.Vocab at 0x7f0e818450a0>,
#  '보호사': <gensim.models.keyedvectors.Vocab at 0x7f0e81845100>,
#  '광주': <gensim.models.keyedvectors.Vocab at 0x7f0e81845160>,
#  '46': <gensim.models.keyedvectors.Vocab at 0x7f0e818451c0>,
#  '번': <gensim.models.keyedvectors.Vocab at 0x7f0e81845220>,
#  '서': <gensim.models.keyedvectors.Vocab at 0x7f0e81845280>,
#  '시설': <gensim.models.keyedvectors.Vocab at 0x7f0e818452e0>,
#  '교회': <gensim.models.keyedvectors.Vocab at 0x7f0e81845340>,
#  '전파': <gensim.models.keyedvectors.Vocab at 0x7f0e818453a0>,
#  '12': <gensim.models.keyedvectors.Vocab at 0x7f0e81845400>,
#  '추가': <gensim.models.keyedvectors.Vocab at 0x7f0e81845460>,
#  '감염': <gensim.models.keyedvectors.Vocab at 0x7f0e818454c0>,
#  '관악구': <gensim.models.keyedvectors.Vocab at 0x7f0e81845520>,
#  '동작구': <gensim.models.keyedvectors.Vocab at 0x7f0e81845580>,
#  '문창': <gensim.models.keyedvectors.Vocab at 0x7f0e818455e0>,
#  '초': <gensim.models.keyedvectors.Vocab at 0x7f0e81845640>,
#  '전수': <gensim.models.keyedvectors.Vocab at 0x7f0e818456a0>,
#  '검사': <gensim.models.keyedvectors.Vocab at 0x7f0e81845700>,
#  '실시': <gensim.models.keyedvectors.Vocab at 0x7f0e81845760>,
#  '동구': <gensim.models.keyedvectors.Vocab at 0x7f0e818457c0>,
#  'CCC': <gensim.models.keyedvectors.Vocab at 0x7f0e81845820>,
#  '실버': <gensim.models.keyedvectors.Vocab at 0x7f0e81845880>,
#  '센터': <gensim.models.keyedvectors.Vocab at 0x7f0e818458e0>,
#  '질병관리본부': <gensim.models.keyedvectors.Vocab at 0x7f0e81845940>,
#  '확진': <gensim.models.keyedvectors.Vocab at 0x7f0e818459a0>,
#  '음압': <gensim.models.keyedvectors.Vocab at 0x7f0e81845a00>,
#  '병실': <gensim.models.keyedvectors.Vocab at 0x7f0e81845a60>,
#  '이송': <gensim.models.keyedvectors.Vocab at 0x7f0e81845ac0>,
#  '절차': <gensim.models.keyedvectors.Vocab at 0x7f0e81845b20>,
#  '밟': <gensim.models.keyedvectors.Vocab at 0x7f0e81845b80>,
#  '들어가': <gensim.models.keyedvectors.Vocab at 0x7f0e81845be0>,
#  '해당': <gensim.models.keyedvectors.Vocab at 0x7f0e81845c40>,
#  '근무': <gensim.models.keyedvectors.Vocab at 0x7f0e81845ca0>,
#  '곳': <gensim.models.keyedvectors.Vocab at 0x7f0e81845d00>,
#  '판정': <gensim.models.keyedvectors.Vocab at 0x7f0e81845d60>,
#  '202071': <gensim.models.keyedvectors.Vocab at 0x7f0e81845dc0>,
#  'News': <gensim.models.keyedvectors.Vocab at 0x7f0e81845e20>,
#  '규': <gensim.models.keyedvectors.Vocab at 0x7f0e81845e80>,
#  '김태환': <gensim.models.keyedvectors.Vocab at 0x7f0e81845ee0>,
#  '음상': <gensim.models.keyedvectors.Vocab at 0x7f0e81845f40>,
#  '준': <gensim.models.keyedvectors.Vocab at 0x7f0e81845fa0>,
#  '이영성': <gensim.models.keyedvectors.Vocab at 0x7f0e81614040>,
#  '이형진': <gensim.models.keyedvectors.Vocab at 0x7f0e816140a0>,
#  '하루': <gensim.models.keyedvectors.Vocab at 0x7f0e81614100>,
#  '35': <gensim.models.keyedvectors.Vocab at 0x7f0e81614160>,
#  '발생': <gensim.models.keyedvectors.Vocab at 0x7f0e816141c0>,
#  '해외': <gensim.models.keyedvectors.Vocab at 0x7f0e81614220>,
#  '유입': <gensim.models.keyedvectors.Vocab at 0x7f0e81614280>,
#  '제외': <gensim.models.keyedvectors.Vocab at 0x7f0e816142e0>,
#  '31': <gensim.models.keyedvectors.Vocab at 0x7f0e81614340>,
#  '감염자': <gensim.models.keyedvectors.Vocab at 0x7f0e816143a0>,
#  '수도': <gensim.models.keyedvectors.Vocab at 0x7f0e81614400>,
#  '광역시': <gensim.models.keyedvectors.Vocab at 0x7f0e81614460>,
#  '서울시': <gensim.models.keyedvectors.Vocab at 0x7f0e816144c0>,
#  '광주시': <gensim.models.keyedvectors.Vocab at 0x7f0e81614520>,
#  '전국': <gensim.models.keyedvectors.Vocab at 0x7f0e81614580>,
#  '17': <gensim.models.keyedvectors.Vocab at 0x7f0e816145e0>,
#  '개': <gensim.models.keyedvectors.Vocab at 0x7f0e81614640>,
#  '시도': <gensim.models.keyedvectors.Vocab at 0x7f0e816146a0>,
#  '지자체': <gensim.models.keyedvectors.Vocab at 0x7f0e81614700>,
#  '0': <gensim.models.keyedvectors.Vocab at 0x7f0e81614760>,
#  '신규': <gensim.models.keyedvectors.Vocab at 0x7f0e816147c0>,
#  '16': <gensim.models.keyedvectors.Vocab at 0x7f0e81614820>,
#  '대전': <gensim.models.keyedvectors.Vocab at 0x7f0e81614880>,
#  '충남': <gensim.models.keyedvectors.Vocab at 0x7f0e816148e0>,
#  '나타났': <gensim.models.keyedvectors.Vocab at 0x7f0e81614940>,
#  '특히': <gensim.models.keyedvectors.Vocab at 0x7f0e816149a0>,
#  '에선': <gensim.models.keyedvectors.Vocab at 0x7f0e81614a00>,
#  '경로': <gensim.models.keyedvectors.Vocab at 0x7f0e81614a60>,
#  '파악': <gensim.models.keyedvectors.Vocab at 0x7f0e81614a90>,
#  '않': <gensim.models.keyedvectors.Vocab at 0x7f0e81614b20>,
#  '로부터': <gensim.models.keyedvectors.Vocab at 0x7f0e81614b80>,
#  '다닌': <gensim.models.keyedvectors.Vocab at 0x7f0e81614be0>,
#  '신도': <gensim.models.keyedvectors.Vocab at 0x7f0e81614c40>,
#  '이르': <gensim.models.keyedvectors.Vocab at 0x7f0e81614ca0>,
#  '무더기': <gensim.models.keyedvectors.Vocab at 0x7f0e81614d00>,
#  '쏟아졌': <gensim.models.keyedvectors.Vocab at 0x7f0e81614d60>,
#  '알': <gensim.models.keyedvectors.Vocab at 0x7f0e81614dc0>,
#  '나왔': <gensim.models.keyedvectors.Vocab at 0x7f0e81614e20>,
#  '◇': <gensim.models.keyedvectors.Vocab at 0x7f0e81614e80>,
#  '모르': <gensim.models.keyedvectors.Vocab at 0x7f0e81614ee0>,
#  '늘어난': <gensim.models.keyedvectors.Vocab at 0x7f0e81614f40>,
#  '72': <gensim.models.keyedvectors.Vocab at 0x7f0e81614fa0>,
#  '그': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2040>,
#  '광': <gensim.models.keyedvectors.Vocab at 0x7f0e814d20a0>,
#  '륵': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2100>,
#  '관련': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2160>,
#  '더': <gensim.models.keyedvectors.Vocab at 0x7f0e814d21c0>,
#  '북구': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2220>,
#  '사랑': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2280>,
#  '진단': <gensim.models.keyedvectors.Vocab at 0x7f0e814d22e0>,
#  '양성': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2340>,
#  '방역': <gensim.models.keyedvectors.Vocab at 0x7f0e814d23a0>,
#  '당국': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2400>,
#  '접촉자': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2460>,
#  '가': <gensim.models.keyedvectors.Vocab at 0x7f0e814d24c0>,
#  '접촉': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2520>,
#  '추정': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2580>,
#  '실제': <gensim.models.keyedvectors.Vocab at 0x7f0e814d25e0>,
#  '26': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2640>,
#  '동안': <gensim.models.keyedvectors.Vocab at 0x7f0e814d26a0>,
#  '28': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2700>,
#  '오전': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2760>,
#  '방문': <gensim.models.keyedvectors.Vocab at 0x7f0e814d27c0>,
#  '다가': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2820>,
#  '이후': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2880>,
#  '아직': <gensim.models.keyedvectors.Vocab at 0x7f0e814d28e0>,
#  '접점': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2940>,
#  '거주': <gensim.models.keyedvectors.Vocab at 0x7f0e814d29a0>,
#  '60': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2a00>,
#  '남성': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2a60>,
#  '67': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2ac0>,
#  '여성': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2b20>,
#  '70': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2b80>,
#  '48': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2be0>,
#  '사실': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2c40>,
#  '56': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2ca0>,
#  '아들': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2d00>,
#  '30': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2d60>,
#  '71': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2dc0>,
#  '와': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2e20>,
#  '별도': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2e80>,
#  '불명확': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2ee0>,
#  '금양': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2f40>,
#  '오피스텔': <gensim.models.keyedvectors.Vocab at 0x7f0e814d2fa0>,
#  '43': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e040>,
#  '전남': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e0a0>,
#  '자매': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e100>,
#  '동생': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e160>,
#  '만난': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e1c0>,
#  '37': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e220>,
#  '셈': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e280>,
#  '들': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e2e0>,
#  '36': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e340>,
#  '→': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e3a0>,
#  '이루': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e400>,
#  '가족': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e460>,
#  '초등학생': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e4c0>,
#  '교내': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e520>,
#  '우려': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e580>,
#  '초등': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e5e0>,
#  '학교': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e640>,
#  '학년': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e6a0>,
#  '학생': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e700>,
#  '포함': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e760>,
#  '폐쇄': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e7c0>,
#  '교직원': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e820>,
#  '180': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e880>,
#  '벌어졌': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e8e0>,
#  '119': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e940>,
#  '122': <gensim.models.keyedvectors.Vocab at 0x7f0e8125e9a0>,
#  '관계': <gensim.models.keyedvectors.Vocab at 0x7f0e8125ea00>,
#  '신사동': <gensim.models.keyedvectors.Vocab at 0x7f0e8125ea60>,
#  '62': <gensim.models.keyedvectors.Vocab at 0x7f0e8125eac0>,
#  '세': <gensim.models.keyedvectors.Vocab at 0x7f0e8125eb20>,
#  '113': <gensim.models.keyedvectors.Vocab at 0x7f0e8125eb80>,
#  '정확': <gensim.models.keyedvectors.Vocab at 0x7f0e8125ebe0>,
#  '성별': <gensim.models.keyedvectors.Vocab at 0x7f0e8125ec40>,
#  '공개': <gensim.models.keyedvectors.Vocab at 0x7f0e8125eca0>,
#  '으나': <gensim.models.keyedvectors.Vocab at 0x7f0e8125ed00>,
#  '121': <gensim.models.keyedvectors.Vocab at 0x7f0e8125ed60>,
#  '다른': <gensim.models.keyedvectors.Vocab at 0x7f0e8125edc0>,
#  '123': <gensim.models.keyedvectors.Vocab at 0x7f0e8125ee20>,
#  '84': <gensim.models.keyedvectors.Vocab at 0x7f0e8125ee80>,
#  '재학': <gensim.models.keyedvectors.Vocab at 0x7f0e8125eee0>,
#  '밝혀졌': <gensim.models.keyedvectors.Vocab at 0x7f0e8125ef40>,
#  '124': <gensim.models.keyedvectors.Vocab at 0x7f0e8125efa0>,
#  '125': <gensim.models.keyedvectors.Vocab at 0x7f0e81163040>,
#  '노량진': <gensim.models.keyedvectors.Vocab at 0x7f0e811630a0>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x7f0e81163100>,
#  '54': <gensim.models.keyedvectors.Vocab at 0x7f0e81163160>,
#  '조사': <gensim.models.keyedvectors.Vocab at 0x7f0e811631c0>,
#  '격리': <gensim.models.keyedvectors.Vocab at 0x7f0e81163220>,
#  '강': <gensim.models.keyedvectors.Vocab at 0x7f0e81163280>,
#  '강동구': <gensim.models.keyedvectors.Vocab at 0x7f0e811632e0>,
#  '고양시': <gensim.models.keyedvectors.Vocab at 0x7f0e81163340>,
#  '단': <gensim.models.keyedvectors.Vocab at 0x7f0e811633a0>,
#  '밝혀': <gensim.models.keyedvectors.Vocab at 0x7f0e81163400>,
#  '은평구': <gensim.models.keyedvectors.Vocab at 0x7f0e81163460>,
#  '타': <gensim.models.keyedvectors.Vocab at 0x7f0e811634c0>,
#  '판매': <gensim.models.keyedvectors.Vocab at 0x7f0e81163520>,
#  '업체': <gensim.models.keyedvectors.Vocab at 0x7f0e81163580>,
#  '이력': <gensim.models.keyedvectors.Vocab at 0x7f0e811635e0>,
#  '밖': <gensim.models.keyedvectors.Vocab at 0x7f0e81163640>,
#  '동발': <gensim.models.keyedvectors.Vocab at 0x7f0e811636a0>,
#  '파주시': <gensim.models.keyedvectors.Vocab at 0x7f0e81163700>,
#  '파': <gensim.models.keyedvectors.Vocab at 0x7f0e81163760>,
#  '주': <gensim.models.keyedvectors.Vocab at 0x7f0e811637c0>,
#  '의정부': <gensim.models.keyedvectors.Vocab at 0x7f0e81163820>,
#  '분류': <gensim.models.keyedvectors.Vocab at 0x7f0e81163880>,
#  '됐으나': <gensim.models.keyedvectors.Vocab at 0x7f0e811638e0>,
#  '역시': <gensim.models.keyedvectors.Vocab at 0x7f0e81163940>,
#  '김포시': <gensim.models.keyedvectors.Vocab at 0x7f0e811639a0>,
#  '파키스탄': <gensim.models.keyedvectors.Vocab at 0x7f0e81163a00>,
#  '국적': <gensim.models.keyedvectors.Vocab at 0x7f0e81163a60>,
#  '외국인': <gensim.models.keyedvectors.Vocab at 0x7f0e81163ac0>,
#  '38': <gensim.models.keyedvectors.Vocab at 0x7f0e81163b20>,
#  '29': <gensim.models.keyedvectors.Vocab at 0x7f0e81163b80>,
#  '인천': <gensim.models.keyedvectors.Vocab at 0x7f0e81163be0>,
#  '공항': <gensim.models.keyedvectors.Vocab at 0x7f0e81163c40>,
#  '입국': <gensim.models.keyedvectors.Vocab at 0x7f0e81163ca0>,
#  '했으며': <gensim.models.keyedvectors.Vocab at 0x7f0e81163d00>,
#  '화성시': <gensim.models.keyedvectors.Vocab at 0x7f0e81163d60>,
#  '직장': <gensim.models.keyedvectors.Vocab at 0x7f0e81163dc0>,
#  '일': <gensim.models.keyedvectors.Vocab at 0x7f0e81163e20>,
#  '우주': <gensim.models.keyedvectors.Vocab at 0x7f0e81163e80>,
#  '탄': <gensim.models.keyedvectors.Vocab at 0x7f0e81163ee0>,
#  '통보': <gensim.models.keyedvectors.Vocab at 0x7f0e81163f40>,
#  '남양주': <gensim.models.keyedvectors.Vocab at 0x7f0e81163fa0>,
#  '산동': <gensim.models.keyedvectors.Vocab at 0x7f0e81199040>,
#  '주민': <gensim.models.keyedvectors.Vocab at 0x7f0e811990a0>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x7f0e81199100>,
#  '왔으며': <gensim.models.keyedvectors.Vocab at 0x7f0e81199160>,
#  '해제': <gensim.models.keyedvectors.Vocab at 0x7f0e811991c0>,
#  '서구': <gensim.models.keyedvectors.Vocab at 0x7f0e81199220>,
#  '변동': <gensim.models.keyedvectors.Vocab at 0x7f0e81199280>,
#  '전일': <gensim.models.keyedvectors.Vocab at 0x7f0e811992e0>,
#  '남편': <gensim.models.keyedvectors.Vocab at 0x7f0e81199340>,
#  '기저': <gensim.models.keyedvectors.Vocab at 0x7f0e811993a0>,
#  '질환': <gensim.models.keyedvectors.Vocab at 0x7f0e81199400>,
#  '천안': <gensim.models.keyedvectors.Vocab at 0x7f0e81199460>,
#  '카자흐스탄': <gensim.models.keyedvectors.Vocab at 0x7f0e811994c0>,
#  '천안시': <gensim.models.keyedvectors.Vocab at 0x7f0e81199520>,
#  '112': <gensim.models.keyedvectors.Vocab at 0x7f0e81199580>,
#  '아시아': <gensim.models.keyedvectors.Vocab at 0x7f0e811995e0>,
#  '경제': <gensim.models.keyedvectors.Vocab at 0x7f0e81199640>,
#  '뉴욕': <gensim.models.keyedvectors.Vocab at 0x7f0e811996a0>,
#  '백종민': <gensim.models.keyedvectors.Vocab at 0x7f0e81199700>,
#  '특파원': <gensim.models.keyedvectors.Vocab at 0x7f0e81199760>,
#  '지표': <gensim.models.keyedvectors.Vocab at 0x7f0e811997c0>,
#  '음': <gensim.models.keyedvectors.Vocab at 0x7f0e81199820>,
#  '보여': <gensim.models.keyedvectors.Vocab at 0x7f0e81199880>,
#  '사례': <gensim.models.keyedvectors.Vocab at 0x7f0e811998e0>,
#  '관광공사': <gensim.models.keyedvectors.Vocab at 0x7f0e81199940>,
#  '중국': <gensim.models.keyedvectors.Vocab at 0x7f0e811999a0>,
#  '여행사': <gensim.models.keyedvectors.Vocab at 0x7f0e81199a00>,
#  '트립': <gensim.models.keyedvectors.Vocab at 0x7f0e81199a60>,
#  '닷컴': <gensim.models.keyedvectors.Vocab at 0x7f0e81199ac0>,
#  '여행': <gensim.models.keyedvectors.Vocab at 0x7f0e81199b20>,
#  '상품': <gensim.models.keyedvectors.Vocab at 0x7f0e81199b80>,
#  '라이브': <gensim.models.keyedvectors.Vocab at 0x7f0e81199be0>,
#  '커머스': <gensim.models.keyedvectors.Vocab at 0x7f0e81199c40>,
#  '200': <gensim.models.keyedvectors.Vocab at 0x7f0e81199ca0>,
#  '몰리': <gensim.models.keyedvectors.Vocab at 0x7f0e81199d00>,
#  '흥행': <gensim.models.keyedvectors.Vocab at 0x7f0e81199d60>,
#  '성공': <gensim.models.keyedvectors.Vocab at 0x7f0e81199dc0>,
#  '행사': <gensim.models.keyedvectors.Vocab at 0x7f0e81199e20>,
#  '프로모션': <gensim.models.keyedvectors.Vocab at 0x7f0e81199e80>,
#  '소식': <gensim.models.keyedvectors.Vocab at 0x7f0e81199ee0>,
#  '알려': <gensim.models.keyedvectors.Vocab at 0x7f0e81199f40>,
#  '관측': <gensim.models.keyedvectors.Vocab at 0x7f0e81199fa0>,
#  '확대': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49040>,
#  '해석': <gensim.models.keyedvectors.Vocab at 0x7f0e7af490a0>,
#  '해명': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49100>,
#  '자료': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49160>,
#  '냈': <gensim.models.keyedvectors.Vocab at 0x7f0e7af491c0>,
#  '저녁': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49220>,
#  '슈퍼': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49280>,
#  '보스': <gensim.models.keyedvectors.Vocab at 0x7f0e7af492e0>,
#  '쇼': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49340>,
#  '관광': <gensim.models.keyedvectors.Vocab at 0x7f0e7af493a0>,
#  '판촉': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49400>,
#  '나섰': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49460>,
#  '지켜': <gensim.models.keyedvectors.Vocab at 0x7f0e7af494c0>,
#  '봤': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49520>,
#  '좋': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49580>,
#  '아요': <gensim.models.keyedvectors.Vocab at 0x7f0e7af495e0>,
#  '표시': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49640>,
#  '달할': <gensim.models.keyedvectors.Vocab at 0x7f0e7af496a0>,
#  '정도': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49700>,
#  '호응': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49760>,
#  '공동': <gensim.models.keyedvectors.Vocab at 0x7f0e7af497c0>,
#  '창업자': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49820>,
#  '량': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49880>,
#  '젠': <gensim.models.keyedvectors.Vocab at 0x7f0e7af498e0>,
#  '회장': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49940>,
#  '직접': <gensim.models.keyedvectors.Vocab at 0x7f0e7af499a0>,
#  '출연': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49a00>,
#  '여행지': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49a60>,
#  '소개': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49ac0>,
#  '호텔': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49b20>,
#  '숙박': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49b80>,
#  '할인': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49be0>,
#  '이벤트': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49c40>,
#  '복장': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49ca0>,
#  '강남': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49d00>,
#  '스타일': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49d60>,
#  '추': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49dc0>,
#  '분위기': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49e20>,
#  '인터': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49e80>,
#  '쉐라': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49ee0>,
#  '톤': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49f40>,
#  '유명': <gensim.models.keyedvectors.Vocab at 0x7f0e7af49fa0>,
#  '씨': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72040>,
#  '통해서': <gensim.models.keyedvectors.Vocab at 0x7f0e7af720a0>,
#  '도중': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72100>,
#  '일부': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72160>,
#  '모두': <gensim.models.keyedvectors.Vocab at 0x7f0e7af721c0>,
#  '팔렸': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72220>,
#  '멘': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72280>,
#  '트': <gensim.models.keyedvectors.Vocab at 0x7f0e7af722e0>,
#  '너무': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72340>,
#  '많': <gensim.models.keyedvectors.Vocab at 0x7f0e7af723a0>,
#  '중국인': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72400>,
#  '속': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72460>,
#  '나온': <gensim.models.keyedvectors.Vocab at 0x7f0e7af724f0>,
#  '사전': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72520>,
#  '형식': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72580>,
#  '안정': <gensim.models.keyedvectors.Vocab at 0x7f0e7af725e0>,
#  '금감원': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72640>,
#  '2018': <gensim.models.keyedvectors.Vocab at 0x7f0e7af726a0>,
#  '11': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72700>,
#  '투자자': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72760>,
#  '전액': <gensim.models.keyedvectors.Vocab at 0x7f0e7af727c0>,
#  '배상': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72820>,
#  '결정': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72880>,
#  '금융': <gensim.models.keyedvectors.Vocab at 0x7f0e7af728e0>,
#  '투자': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72940>,
#  '분쟁': <gensim.models.keyedvectors.Vocab at 0x7f0e7af729a0>,
#  '조정': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72a00>,
#  '사상': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72a60>,
#  '첫': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72ac0>,
#  '반환': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72b20>,
#  '운용': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72b80>,
#  '고객': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72be0>,
#  '속였': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72c40>,
#  '판매사': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72ca0>,
#  '검증': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72d00>,
#  '안': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72d60>,
#  '앵커': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72dc0>,
#  '환매': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72e20>,
#  '중단': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72e80>,
#  '라임': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72ee0>,
#  '자산': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72f40>,
#  '무역': <gensim.models.keyedvectors.Vocab at 0x7f0e7af72fa0>,
#  '펀드': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94040>,
#  '감독원': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab940a0>,
#  '처음': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94100>,
#  '원금': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94160>,
#  '돌려주': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab941c0>,
#  '내렸': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94220>,
#  '피해자': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94280>,
#  '환영': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab942e0>,
#  '뜻': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94340>,
#  '는데': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab943a0>,
#  '조정안': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94400>,
#  '수용': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94460>,
#  '검토': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab944c0>,
#  '입장': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94520>,
#  '이뤄질지': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94580>,
#  '미지수': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab945e0>,
#  '건': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94640>,
#  '산': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab946a0>,
#  '라고': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94700>,
#  '같': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94760>,
#  '계약': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab947c0>,
#  '체결': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94820>,
#  '상당': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94880>,
#  '부분': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab948e0>,
#  '손실': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94940>,
#  '제대로': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab949a0>,
#  '없이': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94a00>,
#  '정성': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94a60>,
#  '웅': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94ac0>,
#  '부원': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94b20>,
#  '장보': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94b80>,
#  '제안서': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94be0>,
#  '수익': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94c40>,
#  '핵심': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94ca0>,
#  '정보': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94d00>,
#  '허위': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94d60>,
#  '부실': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94dc0>,
#  '기재': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94e20>,
#  '은행': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94e80>,
#  '증권사': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94ee0>,
#  '면밀': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94f40>,
#  '출시': <gensim.models.keyedvectors.Vocab at 0x7f0e7ab94fa0>,
#  '를': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b040>,
#  '원만': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b0a0>,
#  '된다는': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b100>,
#  '전제': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b160>,
#  '아래': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b1c0>,
#  '611': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b220>,
#  '억': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b2b0>,
#  '내다봤': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b2e0>,
#  '한다는': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b340>,
#  '불법': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b3a0>,
#  '모든': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b400>,
#  '완전': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b460>,
#  '끝': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b4c0>,
#  '속인': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b520>,
#  '상태': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b580>,
#  '라': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b5e0>,
#  '애초': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b640>,
#  '이건': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b6a0>,
#  '원천': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b700>,
#  '취소': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b760>,
#  '당연': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b7c0>,
#  '생각': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b820>,
#  '합니다': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b880>,
#  '정의': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b8e0>,
#  '책임': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b940>,
#  '명백': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8b9a0>,
#  '인정': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8ba00>,
#  '다며': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8ba60>,
#  '사모': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8bac0>,
#  '해결': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8bb20>,
#  '위한': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8bb80>,
#  '중요': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8bbe0>,
#  '선례': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8bc40>,
#  '하지만': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8bca0>,
#  '갈': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8bd00>,
#  '길': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8bd60>,
#  '강제성': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8bdc0>,
#  '받아들여야': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8be20>,
#  '성립': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8be80>,
#  '때문': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8bee0>,
#  '문': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8bf40>,
#  '접수': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae8bfa0>,
#  '뒤': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9040>,
#  '쉽': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea90a0>,
#  '받아들이': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9100>,
#  '어렵': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9160>,
#  '통지': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea91c0>,
#  '해야': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9220>,
#  '거부': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9280>,
#  '법정': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea92e0>,
#  '다툼': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9340>,
#  '불가피': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea93a0>,
#  '영향': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9400>,
#  '미칠': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9460>,
#  '보입니다': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea94c0>,
#  'YTN': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9520>,
#  'ytncokr': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9580>,
#  '롯데마트': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea95e0>,
#  '홈플러스': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9640>,
#  '침방울': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea96a0>,
#  '차단': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9700>,
#  '마스크': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9760>,
#  '대부분': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea97c0>,
#  '편의점': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9820>,
#  '살': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9880>,
#  '당': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea98e0>,
#  '품절': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9940>,
#  '대란': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea99a0>,
#  '못': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9a00>,
#  '구했': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9a60>,
#  '대형': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9ac0>,
#  '마트': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9b20>,
#  '백화점': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9b80>,
#  '매장': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9be0>,
#  '풀렸': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9c40>,
#  '초반': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9ca0>,
#  '물량': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9d00>,
#  '점차': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9d60>,
#  '많이': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9dc0>,
#  '수급': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9e20>,
#  '원활': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9e80>,
#  '해질': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9ee0>,
#  '을지': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9f40>,
#  '주목': <gensim.models.keyedvectors.Vocab at 0x7f0e7aea9fa0>,
#  '됩니다': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49040>,
#  '개점': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae490a0>,
#  '분': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49100>,
#  '긴': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49160>,
#  '생겼': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae491c0>,
#  '지점': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49220>,
#  '백': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49280>,
#  '장': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae492e0>,
#  '여름': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49340>,
#  '니까': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae493a0>,
#  '더우': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49400>,
#  '비말': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49460>,
#  '시원': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae494c0>,
#  '해서': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49520>,
#  '러': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49580>,
#  '왔': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae495e0>,
#  '셨': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49640>,
#  '어요': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae496a0>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49700>,
#  '쯤': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49760>,
#  '요': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae497c0>,
#  '무더운': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49820>,
#  '여름철': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49880>,
#  '숨쉬기': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae498e0>,
#  '편해': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49940>,
#  '인기': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae499a0>,
#  '이마트': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49a00>,
#  '겁니다': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49a60>,
#  '장당': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49ac0>,
#  '씩': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49b20>,
#  '점포': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49b80>,
#  '일단': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49be0>,
#  '개시': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49c40>,
#  'GS': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49ca0>,
#  '이외': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49d00>,
#  '세븐일레븐': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49d60>,
#  '평균': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49dc0>,
#  'CU': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49e20>,
#  '백만': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49e80>,
#  '가격': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49ee0>,
#  '975': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49f40>,
#  '묶음': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae49fa0>,
#  '단위': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae6e040>,
#  '팔': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae6e0a0>,
#  '충분': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae6e100>,
#  '늘려': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae6e160>,
#  '나갈': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae6e1c0>,
#  '나': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae6e220>,
#  '롯데': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae6e280>,
#  '760': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae6e2e0>,
#  '신세계': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae6e340>,
#  '580': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae6e3a0>,
#  '700': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae6e400>,
#  '풀리': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae6e460>,
#  '월스트리트': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae6e4c0>,
#  'AFP': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae6e520>,
#  '증시': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae6e580>,
#  '둘러싼': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae6e5e0>,
#  '기대감': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae6e640>,
#  '상승': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae6e6a0>,
#  '출발': <gensim.models.keyedvectors.Vocab at 0x7f0e7ae6e700>,
#  ...}

# %%
#벡터화 작업
def vectorize(tokens):
    result = []
    for token in tokens:
        vectors = []
        for sentence in token:
            # 문장 벡터 = 각 단어의 평균 벡터
            init_v = np.array([0.0]*v_dimension)
            count = 0
            for word in sentence:
                word_vectors = model.wv
                if word in word_vectors.vocab:
                    count +=1
                    v = model.wv[word]
                    init_v = init_v + v
            init_v = init_v / count
            vectors.append(init_v)
        result.append(vectors)
    
    frame = {'article' : df['article'], 'sentence': df['sentence'], 'token': df['token'], 'vector': result }
    result = pd.DataFrame(frame) 
    
    return result

# %%
df = vectorize(df['token'])

# %%
df
# Out:
#                                              article  \
# 0  요양보호사 광주 46번서 요양시설·교회로 전파…12명 추가 감염 서울 관악구서만 7...
# 1  한국관광공사와 중국 최대 여행사인 트립닷컴이 1일 함께 진행한 한국 여행 상품 판매...
# 2  금감원 2018년 11월 이후 투자자 전액 배상 결정 금융투자상품 분쟁조정 사상 첫...
# 3  롯데마트와 홈플러스도 침방울 차단 마스크 판매 본격화 대부분 편의점에서도 살 수 있...
# 4  머니투데이 문병환 기자 머니투데이와 공연 문화허브 M터치 가 펼치는 4대 가요제 중...
# 5  스포츠경향 정세균 국무총리와 노사정 대표들이 1일 오전 10시30분 ‘코로나19 위...
# 6  뉴욕 연합뉴스 오진우 연합인포맥스 특파원 뉴욕증시에서 주요 지수는 1일 양호한 미국...
# 7  코로나19거 전 세계로 확산되는 가운데 미국 뉴욕 맨하탄 웨스트빌리지 7번가 한산한...
# 8  앵커 정부가 6·17 부동산 대책을 내놓은 지 보름가량 됐습니다. 추가 규제를 피한...
# 9  6월 서울 주택 매매가 석달 만에 상승 경기는 0.68% 뛰어 ‘풍선효과’ 뚜렷 아...
#
#                                             sentence  \
# 0  [요양보호사 광주 46번서 요양시설·교회로 전파…12명 추가 감염 서울 관악구서만 ...
# 1  [한국관광공사와 중국 최대 여행사인 트립닷컴이 1일 함께 진행한 한국 여행 상품 판...
# 2  [금감원 2018년 11월 이후 투자자 전액 배상 결정 금융투자상품 분쟁조정 사상 ...
# 3  [롯데마트와 홈플러스도 침방울 차단 마스크 판매 본격화 대부분 편의점에서도 살 수 ...
# 4  [머니투데이 문병환 기자 머니투데이와 공연 문화허브 M터치 가 펼치는 4대 가요, ...
# 5  [스포츠경향 정세균 국무총리와 노사정 대표들이 1일 오전 10시30분 ‘코로나19 ...
# 6  [뉴욕 연합뉴스 오진우 연합인포맥스 특파원 뉴욕증시에서 주요 지수는 1일 양호한 미...
# 7  [코로나19거 전 세계로 확산되는 가운데 미국 뉴욕 맨하탄 웨스트빌리지 7번가 한산...
# 8  [앵커 정부가 6·17 부동산 대책을 내놓은 지 보름가량 됐습니다., 추가 규제를 ...
# 9  [6월 서울 주택 매매가 석달 만에 상승 경기는 0.68% 뛰어 ‘풍선효과’ 뚜렷 ...
#
#                                                token  \
# 0  [[요양, 보호사, 광주, 46, 번, 서, 요양, 시설, 교회, 전파, 12, 명...
# 1  [[한국, 관광공사, 중국, 최대, 여행사, 인, 트립, 닷컴, 1, 진행, 한, ...
# 2  [[금감원, 2018, 11, 이후, 투자자, 전액, 배상, 결정, 금융, 투자, ...
# 3  [[롯데마트, 홈플러스, 도, 침방울, 차단, 마스크, 판매, 본격, 화, 대부분,...
# 4  [[머니, 투데이, 문, 병환, 기자, 머니, 투데이, 공연, 문화, 허브, M, ...
# 5  [[스포츠, 경향, 정세균, 국무총리, 노사정, 대표, 1, 오전, 10, 시, 3...
# 6  [[뉴욕, 연합뉴스, 오진우, 연합, 인포, 맥스, 특파원, 뉴욕, 증시, 주요, ...
# 7  [[코로나, 19, 거, 전, 세계, 확산, 되, 는, 가운데, 미국, 뉴욕, 맨하...
# 8  [[앵커, 정부, 617, 부동산, 대책, 내놓, 은, 지, 보름, 가량, 됐, ....
# 9  [[6, 서울, 주택, 매매, 석, 달, 만, 상승, 경기, 는, 0, ., 68,...
#
#                                               vector
# 0  [[-0.1004460559473658, -0.048762121123774926, ...
# 1  [[-0.08544983807951212, 0.017376393231993113, ...
# 2  [[0.7504085465148091, -0.40503870490938426, 0....
# 3  [[-0.03843088780922699, 0.07523332014014679, 0...
# 4  [[0.19445288507267833, -0.0103965991147561, 0....
# 5  [[0.635544136604842, 0.08541283003218911, 0.83...
# 6  [[0.24626479188308997, -0.28111700323300765, 0...
# 7  [[0.4652947559106079, -0.12442229184406725, 0....
# 8  [[0.7028303413905881, -0.12219022561542013, 0....
# 9  [[0.3041603645803977, -0.20886570956481962, 0....

# %%
#코사인유사도 매트릭스
def similarity_matrix(vectors):
    sim_mat = np.zeros([len(vectors), len(vectors)])
    for i in range(len(vectors)):
        for j in range(len(vectors)):
            sim_mat[i][j] = cosine_similarity(vectors[i].reshape(1, v_dimension), vectors[j].reshape(1, v_dimension))[0,0]
    return sim_mat

# %%
df['SimMatrix'] = df['vector'].apply(similarity_matrix)

# %%
df
# Out:
#                                              article  \
# 0  요양보호사 광주 46번서 요양시설·교회로 전파…12명 추가 감염 서울 관악구서만 7...
# 1  한국관광공사와 중국 최대 여행사인 트립닷컴이 1일 함께 진행한 한국 여행 상품 판매...
# 2  금감원 2018년 11월 이후 투자자 전액 배상 결정 금융투자상품 분쟁조정 사상 첫...
# 3  롯데마트와 홈플러스도 침방울 차단 마스크 판매 본격화 대부분 편의점에서도 살 수 있...
# 4  머니투데이 문병환 기자 머니투데이와 공연 문화허브 M터치 가 펼치는 4대 가요제 중...
# 5  스포츠경향 정세균 국무총리와 노사정 대표들이 1일 오전 10시30분 ‘코로나19 위...
# 6  뉴욕 연합뉴스 오진우 연합인포맥스 특파원 뉴욕증시에서 주요 지수는 1일 양호한 미국...
# 7  코로나19거 전 세계로 확산되는 가운데 미국 뉴욕 맨하탄 웨스트빌리지 7번가 한산한...
# 8  앵커 정부가 6·17 부동산 대책을 내놓은 지 보름가량 됐습니다. 추가 규제를 피한...
# 9  6월 서울 주택 매매가 석달 만에 상승 경기는 0.68% 뛰어 ‘풍선효과’ 뚜렷 아...
#
#                                             sentence  \
# 0  [요양보호사 광주 46번서 요양시설·교회로 전파…12명 추가 감염 서울 관악구서만 ...
# 1  [한국관광공사와 중국 최대 여행사인 트립닷컴이 1일 함께 진행한 한국 여행 상품 판...
# 2  [금감원 2018년 11월 이후 투자자 전액 배상 결정 금융투자상품 분쟁조정 사상 ...
# 3  [롯데마트와 홈플러스도 침방울 차단 마스크 판매 본격화 대부분 편의점에서도 살 수 ...
# 4  [머니투데이 문병환 기자 머니투데이와 공연 문화허브 M터치 가 펼치는 4대 가요, ...
# 5  [스포츠경향 정세균 국무총리와 노사정 대표들이 1일 오전 10시30분 ‘코로나19 ...
# 6  [뉴욕 연합뉴스 오진우 연합인포맥스 특파원 뉴욕증시에서 주요 지수는 1일 양호한 미...
# 7  [코로나19거 전 세계로 확산되는 가운데 미국 뉴욕 맨하탄 웨스트빌리지 7번가 한산...
# 8  [앵커 정부가 6·17 부동산 대책을 내놓은 지 보름가량 됐습니다., 추가 규제를 ...
# 9  [6월 서울 주택 매매가 석달 만에 상승 경기는 0.68% 뛰어 ‘풍선효과’ 뚜렷 ...
#
#                                                token  \
# 0  [[요양, 보호사, 광주, 46, 번, 서, 요양, 시설, 교회, 전파, 12, 명...
# 1  [[한국, 관광공사, 중국, 최대, 여행사, 인, 트립, 닷컴, 1, 진행, 한, ...
# 2  [[금감원, 2018, 11, 이후, 투자자, 전액, 배상, 결정, 금융, 투자, ...
# 3  [[롯데마트, 홈플러스, 도, 침방울, 차단, 마스크, 판매, 본격, 화, 대부분,...
# 4  [[머니, 투데이, 문, 병환, 기자, 머니, 투데이, 공연, 문화, 허브, M, ...
# 5  [[스포츠, 경향, 정세균, 국무총리, 노사정, 대표, 1, 오전, 10, 시, 3...
# 6  [[뉴욕, 연합뉴스, 오진우, 연합, 인포, 맥스, 특파원, 뉴욕, 증시, 주요, ...
# 7  [[코로나, 19, 거, 전, 세계, 확산, 되, 는, 가운데, 미국, 뉴욕, 맨하...
# 8  [[앵커, 정부, 617, 부동산, 대책, 내놓, 은, 지, 보름, 가량, 됐, ....
# 9  [[6, 서울, 주택, 매매, 석, 달, 만, 상승, 경기, 는, 0, ., 68,...
#
#                                               vector  \
# 0  [[-0.1004460559473658, -0.048762121123774926, ...
# 1  [[-0.08544983807951212, 0.017376393231993113, ...
# 2  [[0.7504085465148091, -0.40503870490938426, 0....
# 3  [[-0.03843088780922699, 0.07523332014014679, 0...
# 4  [[0.19445288507267833, -0.0103965991147561, 0....
# 5  [[0.635544136604842, 0.08541283003218911, 0.83...
# 6  [[0.24626479188308997, -0.28111700323300765, 0...
# 7  [[0.4652947559106079, -0.12442229184406725, 0....
# 8  [[0.7028303413905881, -0.12219022561542013, 0....
# 9  [[0.3041603645803977, -0.20886570956481962, 0....
#
#                                            SimMatrix
# 0  [[1.0, 0.8390463844682985, 0.38402217976241126...
# 1  [[0.9999999999999994, 0.8753952189311108, 0.22...
# 2  [[1.0, 0.6849624598007038, 0.9491063294782923,...
# 3  [[1.0000000000000004, 0.5431313853998593, 0.29...
# 4  [[0.9999999999999999, 0.020770213584794636, -0...
# 5  [[0.9999999999999997, 0.7537380932719095, 0.85...
# 6  [[1.0000000000000004, 0.5223812823305478, 0.53...
# 7  [[1.0000000000000002, 0.3847769690682543, 0.64...
# 8  [[0.9999999999999997, 0.6869661633995391, 0.68...
# 9  [[0.9999999999999997, 0.34999870105711894, 0.8...

# %%
#코사인 유사도를 활용해서 각 문장마다 점수 매기기
#pagerank 사용
def calculate_score(sim_matrix):
    nx_graph = nx.from_numpy_array(sim_matrix)
    scores = nx.pagerank(nx_graph)
    return scores

# %%
df['score'] = df['SimMatrix'].apply(calculate_score)

# %%
df
# Out:
#                                              article  \
# 0  요양보호사 광주 46번서 요양시설·교회로 전파…12명 추가 감염 서울 관악구서만 7...
# 1  한국관광공사와 중국 최대 여행사인 트립닷컴이 1일 함께 진행한 한국 여행 상품 판매...
# 2  금감원 2018년 11월 이후 투자자 전액 배상 결정 금융투자상품 분쟁조정 사상 첫...
# 3  롯데마트와 홈플러스도 침방울 차단 마스크 판매 본격화 대부분 편의점에서도 살 수 있...
# 4  머니투데이 문병환 기자 머니투데이와 공연 문화허브 M터치 가 펼치는 4대 가요제 중...
# 5  스포츠경향 정세균 국무총리와 노사정 대표들이 1일 오전 10시30분 ‘코로나19 위...
# 6  뉴욕 연합뉴스 오진우 연합인포맥스 특파원 뉴욕증시에서 주요 지수는 1일 양호한 미국...
# 7  코로나19거 전 세계로 확산되는 가운데 미국 뉴욕 맨하탄 웨스트빌리지 7번가 한산한...
# 8  앵커 정부가 6·17 부동산 대책을 내놓은 지 보름가량 됐습니다. 추가 규제를 피한...
# 9  6월 서울 주택 매매가 석달 만에 상승 경기는 0.68% 뛰어 ‘풍선효과’ 뚜렷 아...
#
#                                             sentence  \
# 0  [요양보호사 광주 46번서 요양시설·교회로 전파…12명 추가 감염 서울 관악구서만 ...
# 1  [한국관광공사와 중국 최대 여행사인 트립닷컴이 1일 함께 진행한 한국 여행 상품 판...
# 2  [금감원 2018년 11월 이후 투자자 전액 배상 결정 금융투자상품 분쟁조정 사상 ...
# 3  [롯데마트와 홈플러스도 침방울 차단 마스크 판매 본격화 대부분 편의점에서도 살 수 ...
# 4  [머니투데이 문병환 기자 머니투데이와 공연 문화허브 M터치 가 펼치는 4대 가요, ...
# 5  [스포츠경향 정세균 국무총리와 노사정 대표들이 1일 오전 10시30분 ‘코로나19 ...
# 6  [뉴욕 연합뉴스 오진우 연합인포맥스 특파원 뉴욕증시에서 주요 지수는 1일 양호한 미...
# 7  [코로나19거 전 세계로 확산되는 가운데 미국 뉴욕 맨하탄 웨스트빌리지 7번가 한산...
# 8  [앵커 정부가 6·17 부동산 대책을 내놓은 지 보름가량 됐습니다., 추가 규제를 ...
# 9  [6월 서울 주택 매매가 석달 만에 상승 경기는 0.68% 뛰어 ‘풍선효과’ 뚜렷 ...
#
#                                                token  \
# 0  [[요양, 보호사, 광주, 46, 번, 서, 요양, 시설, 교회, 전파, 12, 명...
# 1  [[한국, 관광공사, 중국, 최대, 여행사, 인, 트립, 닷컴, 1, 진행, 한, ...
# 2  [[금감원, 2018, 11, 이후, 투자자, 전액, 배상, 결정, 금융, 투자, ...
# 3  [[롯데마트, 홈플러스, 도, 침방울, 차단, 마스크, 판매, 본격, 화, 대부분,...
# 4  [[머니, 투데이, 문, 병환, 기자, 머니, 투데이, 공연, 문화, 허브, M, ...
# 5  [[스포츠, 경향, 정세균, 국무총리, 노사정, 대표, 1, 오전, 10, 시, 3...
# 6  [[뉴욕, 연합뉴스, 오진우, 연합, 인포, 맥스, 특파원, 뉴욕, 증시, 주요, ...
# 7  [[코로나, 19, 거, 전, 세계, 확산, 되, 는, 가운데, 미국, 뉴욕, 맨하...
# 8  [[앵커, 정부, 617, 부동산, 대책, 내놓, 은, 지, 보름, 가량, 됐, ....
# 9  [[6, 서울, 주택, 매매, 석, 달, 만, 상승, 경기, 는, 0, ., 68,...
#
#                                               vector  \
# 0  [[-0.1004460559473658, -0.048762121123774926, ...
# 1  [[-0.08544983807951212, 0.017376393231993113, ...
# 2  [[0.7504085465148091, -0.40503870490938426, 0....
# 3  [[-0.03843088780922699, 0.07523332014014679, 0...
# 4  [[0.19445288507267833, -0.0103965991147561, 0....
# 5  [[0.635544136604842, 0.08541283003218911, 0.83...
# 6  [[0.24626479188308997, -0.28111700323300765, 0...
# 7  [[0.4652947559106079, -0.12442229184406725, 0....
# 8  [[0.7028303413905881, -0.12219022561542013, 0....
# 9  [[0.3041603645803977, -0.20886570956481962, 0....
#
#                                            SimMatrix  \
# 0  [[1.0, 0.8390463844682985, 0.38402217976241126...
# 1  [[0.9999999999999994, 0.8753952189311108, 0.22...
# 2  [[1.0, 0.6849624598007038, 0.9491063294782923,...
# 3  [[1.0000000000000004, 0.5431313853998593, 0.29...
# 4  [[0.9999999999999999, 0.020770213584794636, -0...
# 5  [[0.9999999999999997, 0.7537380932719095, 0.85...
# 6  [[1.0000000000000004, 0.5223812823305478, 0.53...
# 7  [[1.0000000000000002, 0.3847769690682543, 0.64...
# 8  [[0.9999999999999997, 0.6869661633995391, 0.68...
# 9  [[0.9999999999999997, 0.34999870105711894, 0.8...
#
#                                                score
# 0  {0: 0.01795871228825599, 1: 0.0194407872547084...
# 1  {0: 0.11038639862752907, 1: 0.1144507171183583...
# 2  {0: 0.08284668298683674, 1: 0.0785451733839945...
# 3  {0: 0.08138790359620644, 1: 0.0553330965831385...
# 4  {0: 0.02732887650814984, 1: 0.0510182957113229...
# 5  {0: 0.029298134608698213, 1: 0.031697616647051...
# 6  {0: 0.03955025430747894, 1: 0.0345649053063711...
# 7  {0: 0.060645582370942946, 1: 0.057909049775027...
# 8  {0: 0.06874896041402666, 1: 0.0669202877319058...
# 9  {0: 0.09490203110443626, 1: 0.0565733248059762...

# %% [markdown]
# # Result - base

# %%
def ranked_sentences(sentences, scores, n=3):
    top_scores = sorted(((scores[i],s, i) for i,s in enumerate(sentences)), 
                        key=lambda x : x[0], reverse=True)
    top_n_sentences = [sentence for score, sentence, order in top_scores[:n]]
    return " ".join(top_n_sentences)

# %%
df['summary'] = df.apply(lambda x: 
                            ranked_sentences(x.sentence, 
                            x.score), axis=1)

# %%
temp = df[['article','summary']]

# %%
for i in range(3,5):
    print(i+1,'번 문서')
    print('원문 :',temp.loc[i].article)
    print('')
    print('요약 :',temp.loc[i].summary)
    print('')
# Out:
# 4 번 문서
# 원문 : 롯데마트와 홈플러스도 침방울 차단 마스크 판매 본격화 대부분 편의점에서도 살 수 있어…1인당 구매 제한 없어 앵커 품절 대란으로 쉽게 못 구했던 침방울 차단 마스크가 대형 마트와 백화점 편의점 등 전국 오프라인 매장에 본격적으로 풀렸습니다. 아직 초반이라 물량이 많지 않지만 점차 더 많이 공급되면서 수급이 원활해질 수 있을지 주목됩니다. 차유정 기자입니다. 기자 마트 개점 30분 전부터 긴 줄이 생겼습니다. 침방울 차단용 마스크 사려는 사람들입니다. 해당 지점에서 준비한 물량 천6백 장은 30분 만에 동났습니다. 허희정 서울 응암동 여름이니까 너무 더우니까 비말이 시원하다고 해서 사러 왔습니다. 언제 오셨어요 9시 15분쯤에요. 무더운 여름철에 숨쉬기 편해 인기가 많은 침방울 차단 마스크가 오프라인 매장에 본격적으로 풀렸습니다. 이마트에 이어 롯데마트와 홈플러스도 침방울 차단 마스크 판매를 본격화한 겁니다. 롯데마트는 장당 5백 원씩 전 점포에서 일단 16만 장을 팔고 홈플러스도 장당 5 6백 원에 이번 주에만 30만 장을 판매할 계획입니다. 대부분 편의점에서도 살 수 있게 됐습니다. 특히 편의점은 1인당 구매 제한이 없습니다. 지난달부터 판매를 개시한 GS25 이외에 세븐일레븐은 전 점포에서 하루 평균 5만 장을 CU는 전국 만4천 개 점포에서 한 주에 50만 장을 이마트 24는 첫 주에만 백만 장을 공급합니다. 장당 가격은 CU와 세븐일레븐이 각각 6백 원 이마트 6백 원과 975원 등으로 대부분 5개 묶음 단위로 판매됩니다. 아직은 한 지점에는 팔 수 있는 물량이 충분치 않지만 물량 공급을 점차 늘려나갈 계획입니다. 백화점도 판매에 나서 롯데는 장당 760원에 신세계는 장당 580 700원에 공급을 시작했습니다. 침방울 차단용 마스크가 전국 오프라인 매장에 본격적으로 풀리기 시작하면서 수급이 원활해질지 수 있을지 주목됩니다. YTN 차유정입니다.
#
# 요약 : 롯데마트와 홈플러스도 침방울 차단 마스크 판매 본격화 대부분 편의점에서도 살 수 있어…1인당 구매 제한 없어 앵커 품절 대란으로 쉽게 못 구했던 침방울 차단 마스크가 대형 마트와 백화점 편의점 등 전국 오프라인 매장에 본격적으로 풀렸습니다. 무더운 여름철에 숨쉬기 편해 인기가 많은 침방울 차단 마스크가 오프라인 매장에 본격적으로 풀렸습니다. 특히 편의점은 1인당 구매 제한이 없습니다.
#
# 5 번 문서
# 원문 : 머니투데이 문병환 기자 머니투데이와 공연 문화허브 M터치 가 펼치는 4대 가요제 중심 연중 힐링음악 나눔 플래툰 7월 4일생 디어 헌터 하얀전쟁 등 베트남 전쟁을 소재로 한 여러 영화 중에서 가장 색다른 영화를 꼽으라면 굿모닝 베트남 을 첫손에 꼽을 수 있겠다. 로빈 윌리암스 주연의 굿모닝 베트남 1987 은 전장의 참혹함을 다룬 다른 영화들과 달리 전쟁의 비극 속에서 미국 공군 라디오DJ 애드리안 크로나워. 로빈 윌리암스 분 의 속사포 같은 원맨쇼 진행과 풍자성 코미디가 크게 부각되는 점에서 특별하다. 굿모닝 베트남 을 관통하는 상징과 백미는 전투나 테러가 아니라 루이 암스트롱의 세계적 팝명곡 What A Wonderful World 와 1965년경 베트남 내 전쟁과 평화의 양면을 보여주는 풍경들이다. 방송금지사항들을 깨뜨리는 돌직구성 멘트로 인기스타가 된 라디오DJ는 음악선곡에서도 신나는 로큰롤 곡 I Feel Good 제임스 브라운 을 틀고 고통 속의 장병들은 이런 멘트와 음악에 위로받고 웃고 춤추고 즐거워한다. 전쟁과 평화가 혼재하는 전장 속에서 이 얼마나 멋진 세상인가 What A Wonderful World 란 역설과 반전·평화·인류애의 메시지를 이 영화는 던지고 있다. 캐노피무대 조명 조형물시설 잔디작업을 마치고 올 6월 새롭게 탄생한 영종마로니에공원 은골 H2 사진 문병환 기자 6.25 한국전쟁 이후 장기간에 걸쳐 각종 문화·공연예술행사가 거의 올스톱된 적은 2014년 세월호사태 당시 2년여간 그리고 수개월째 이어지는 현 코로나19사태 때로 기록될 것 같다. 세월호사태 때는 전 한국민이 깊은 슬픔 에 이번 코로나사태 때는 전 세계인이 바이러스와의 전쟁 및 경제적 존망의 공포 속에서 불안한 나날을 보내고 있다. 특히 사회와 인간의 삶을 밝고 건강하게 유지하는데 큰 역할을 하는 문화예술 활동들이 거의 멈추면서 코로나블루 라는 질환이 사회적 문제로 떠오르고 있다. 역사적으로 인류는 전쟁과 세계적 유행병 팬데믹 등을 겪으면서도 결국 다 극복하여 성장 발전을 거듭해왔다. 새롭게 일어설 수 있는 건강한 정신과 희망 용기를 잃지 않았기에 가능했던 것이다. 머니투데이대학가요제 영종국제도시 청소년가요제 영종국제도시 월드뮤직경연대회 인터엠배 직장인밴드페스티벌 등 공연 문화허브 M터치 의 4대 가요제도 이번 코로나19사태로 인해 취소 중단의 기로에서 여러 방향을 모색하게 됐다. 결국 행사 연기를 거듭하면서도 취소를 하지않고 철저한 방역 속 진행 쪽으로 방향설정을 하게 된 것은 이런 음악 공연활동이 코로나블루 치유와 건강한 정신 및 희망 용기의 자양분이 된다는 믿음 때문이었다. 이에 M터치는 오는 7월 4일 토 오후 2020 제2회 영종국제도시 청소년가요제 결선 및 2020 제1회 영종국제도시 월드뮤직경연대회 본선을 영종공항마을 은골 H2 입구 영종마로니에공원 에서 개최한다. 두 가요제는 코로나19 코로나블루 OUT 힐링음악회 란 슬로건으로 사람간 거리두기 및 마스크 착용 등 방역지침을 철저히 준수하면서 버스킹 스타일로 진행될 예정이다. 운서역세권에 위치한 영종공항마을 H2 과 영종마로니에공원 영종하늘도시 9호공원 일대는 이곳 주민들과 공연 문화허브 M터치 가 함께 예술촌으로 가꾸기 위해 2019년부터 몇차례 M터치 버스킹 거리공연 등을 통해 기초환경을 조성해온 영종도의 새로운 생활문화예술 지역이다. 인천시의회·인천중구청·인천공항공사 등에서 주민들이 제안한 예술촌 만들기 계획 에 공감하여 지원책을 실행해줌으로써 이곳의 밤거리가 밝아졌고 LED가로등 다수 설치 영종마로니에공원 내에 캐노피무대 기둥조명시설 조형물 및 잔디조성 작업을 지난 6월 완료함으로써 예술촌을 향한 기본 인프라를 갖추게 됐다. 너구리소굴 별난스페이스 활주로 등 공항마을에 오픈한 문화예술 카페들 사진 문병환 기자 또한 공항마을 내에는 너구리소굴 별난스페이스 활주로 등 특색 있는 음식점과 문화예술 카페 등이 하나씩 들어서면서 점차 예술촌의 모양새를 갖춰가고 있다. 4대 가요제를 통해 국내 최대 규모의 공연팀 풀 pool 을 갖추고 있는 M터치 회장 정현식·슈가버블 회장 한국프랜차이즈산업협회 회장 는 2019년 1월부터 본격적으로 한국의 관문이자 동북아 최대 규모의 복합리조트도시로 조성되고 있는 영종도를 중심으로 공익적 문화예술 나눔활동을 펼치고 있다.
#
# 요약 : 운서역세권에 위치한 영종공항마을 H2 과 영종마로니에공원 영종하늘도시 9호공원 일대는 이곳 주민들과 공연 문화허브 M터치 가 함께 예술촌으로 가꾸기 위해 2019년부터 몇차례 M터치 버스킹 거리공연 등을 통해 기초환경을 조성해온 영종도의 새로운 생활문화예술 지역이다. 세월호사태 때는 전 한국민이 깊은 슬픔 에 이번 코로나사태 때는 전 세계인이 바이러스와의 전쟁 및 경제적 존망의 공포 속에서 불안한 나날을 보내고 있다. 제를 통해 국내 최대 규모의 공연팀 풀 pool 을 갖추고 있는 M터치 회장 정현식·슈가버블 회장 한국프랜차이즈산업협회 회장 는 2019년 1월부터 본격적으로 한국의 관문이자 동북아 최대 규모의 복합리조트도시로 조성되고 있는 영종도를 중심으로 공익적 문화예술 나눔활동을 펼치고 있다.

# %% [markdown]
# # Result - seq

# %%
# score가 높은 순으로 3개만 문장 뽑기
def ranked_sentences_seq(sentences, scores, n=3):
    top_scores = sorted(((scores[i],s, i) for i,s in enumerate(sentences)), 
                        key=lambda x : x[0], reverse=True)
    top_n_sentences_seq = sorted([(order,sentence) for score, sentence, order in top_scores[:n]]
                             , key=lambda x:x[0])
    top_n_sentences = list(map(lambda x:x[1], top_n_sentences_seq))
    return " ".join(top_n_sentences)

# %%
df['summary'] = df.apply(lambda x: 
                            ranked_sentences_seq(x.sentence, 
                            x.score), axis=1)

# %%
temp = df[['article','summary']]

# %%
for i in range(3,5):
    print(i+1,'번 문서')
    print('원문 :',temp.loc[i].article)
    print('')
    print('요약 :',temp.loc[i].summary)
    print('')
# Out:
# 4 번 문서
# 원문 : 롯데마트와 홈플러스도 침방울 차단 마스크 판매 본격화 대부분 편의점에서도 살 수 있어…1인당 구매 제한 없어 앵커 품절 대란으로 쉽게 못 구했던 침방울 차단 마스크가 대형 마트와 백화점 편의점 등 전국 오프라인 매장에 본격적으로 풀렸습니다. 아직 초반이라 물량이 많지 않지만 점차 더 많이 공급되면서 수급이 원활해질 수 있을지 주목됩니다. 차유정 기자입니다. 기자 마트 개점 30분 전부터 긴 줄이 생겼습니다. 침방울 차단용 마스크 사려는 사람들입니다. 해당 지점에서 준비한 물량 천6백 장은 30분 만에 동났습니다. 허희정 서울 응암동 여름이니까 너무 더우니까 비말이 시원하다고 해서 사러 왔습니다. 언제 오셨어요 9시 15분쯤에요. 무더운 여름철에 숨쉬기 편해 인기가 많은 침방울 차단 마스크가 오프라인 매장에 본격적으로 풀렸습니다. 이마트에 이어 롯데마트와 홈플러스도 침방울 차단 마스크 판매를 본격화한 겁니다. 롯데마트는 장당 5백 원씩 전 점포에서 일단 16만 장을 팔고 홈플러스도 장당 5 6백 원에 이번 주에만 30만 장을 판매할 계획입니다. 대부분 편의점에서도 살 수 있게 됐습니다. 특히 편의점은 1인당 구매 제한이 없습니다. 지난달부터 판매를 개시한 GS25 이외에 세븐일레븐은 전 점포에서 하루 평균 5만 장을 CU는 전국 만4천 개 점포에서 한 주에 50만 장을 이마트 24는 첫 주에만 백만 장을 공급합니다. 장당 가격은 CU와 세븐일레븐이 각각 6백 원 이마트 6백 원과 975원 등으로 대부분 5개 묶음 단위로 판매됩니다. 아직은 한 지점에는 팔 수 있는 물량이 충분치 않지만 물량 공급을 점차 늘려나갈 계획입니다. 백화점도 판매에 나서 롯데는 장당 760원에 신세계는 장당 580 700원에 공급을 시작했습니다. 침방울 차단용 마스크가 전국 오프라인 매장에 본격적으로 풀리기 시작하면서 수급이 원활해질지 수 있을지 주목됩니다. YTN 차유정입니다.
#
# 요약 : 롯데마트와 홈플러스도 침방울 차단 마스크 판매 본격화 대부분 편의점에서도 살 수 있어…1인당 구매 제한 없어 앵커 품절 대란으로 쉽게 못 구했던 침방울 차단 마스크가 대형 마트와 백화점 편의점 등 전국 오프라인 매장에 본격적으로 풀렸습니다. 무더운 여름철에 숨쉬기 편해 인기가 많은 침방울 차단 마스크가 오프라인 매장에 본격적으로 풀렸습니다. 특히 편의점은 1인당 구매 제한이 없습니다.
#
# 5 번 문서
# 원문 : 머니투데이 문병환 기자 머니투데이와 공연 문화허브 M터치 가 펼치는 4대 가요제 중심 연중 힐링음악 나눔 플래툰 7월 4일생 디어 헌터 하얀전쟁 등 베트남 전쟁을 소재로 한 여러 영화 중에서 가장 색다른 영화를 꼽으라면 굿모닝 베트남 을 첫손에 꼽을 수 있겠다. 로빈 윌리암스 주연의 굿모닝 베트남 1987 은 전장의 참혹함을 다룬 다른 영화들과 달리 전쟁의 비극 속에서 미국 공군 라디오DJ 애드리안 크로나워. 로빈 윌리암스 분 의 속사포 같은 원맨쇼 진행과 풍자성 코미디가 크게 부각되는 점에서 특별하다. 굿모닝 베트남 을 관통하는 상징과 백미는 전투나 테러가 아니라 루이 암스트롱의 세계적 팝명곡 What A Wonderful World 와 1965년경 베트남 내 전쟁과 평화의 양면을 보여주는 풍경들이다. 방송금지사항들을 깨뜨리는 돌직구성 멘트로 인기스타가 된 라디오DJ는 음악선곡에서도 신나는 로큰롤 곡 I Feel Good 제임스 브라운 을 틀고 고통 속의 장병들은 이런 멘트와 음악에 위로받고 웃고 춤추고 즐거워한다. 전쟁과 평화가 혼재하는 전장 속에서 이 얼마나 멋진 세상인가 What A Wonderful World 란 역설과 반전·평화·인류애의 메시지를 이 영화는 던지고 있다. 캐노피무대 조명 조형물시설 잔디작업을 마치고 올 6월 새롭게 탄생한 영종마로니에공원 은골 H2 사진 문병환 기자 6.25 한국전쟁 이후 장기간에 걸쳐 각종 문화·공연예술행사가 거의 올스톱된 적은 2014년 세월호사태 당시 2년여간 그리고 수개월째 이어지는 현 코로나19사태 때로 기록될 것 같다. 세월호사태 때는 전 한국민이 깊은 슬픔 에 이번 코로나사태 때는 전 세계인이 바이러스와의 전쟁 및 경제적 존망의 공포 속에서 불안한 나날을 보내고 있다. 특히 사회와 인간의 삶을 밝고 건강하게 유지하는데 큰 역할을 하는 문화예술 활동들이 거의 멈추면서 코로나블루 라는 질환이 사회적 문제로 떠오르고 있다. 역사적으로 인류는 전쟁과 세계적 유행병 팬데믹 등을 겪으면서도 결국 다 극복하여 성장 발전을 거듭해왔다. 새롭게 일어설 수 있는 건강한 정신과 희망 용기를 잃지 않았기에 가능했던 것이다. 머니투데이대학가요제 영종국제도시 청소년가요제 영종국제도시 월드뮤직경연대회 인터엠배 직장인밴드페스티벌 등 공연 문화허브 M터치 의 4대 가요제도 이번 코로나19사태로 인해 취소 중단의 기로에서 여러 방향을 모색하게 됐다. 결국 행사 연기를 거듭하면서도 취소를 하지않고 철저한 방역 속 진행 쪽으로 방향설정을 하게 된 것은 이런 음악 공연활동이 코로나블루 치유와 건강한 정신 및 희망 용기의 자양분이 된다는 믿음 때문이었다. 이에 M터치는 오는 7월 4일 토 오후 2020 제2회 영종국제도시 청소년가요제 결선 및 2020 제1회 영종국제도시 월드뮤직경연대회 본선을 영종공항마을 은골 H2 입구 영종마로니에공원 에서 개최한다. 두 가요제는 코로나19 코로나블루 OUT 힐링음악회 란 슬로건으로 사람간 거리두기 및 마스크 착용 등 방역지침을 철저히 준수하면서 버스킹 스타일로 진행될 예정이다. 운서역세권에 위치한 영종공항마을 H2 과 영종마로니에공원 영종하늘도시 9호공원 일대는 이곳 주민들과 공연 문화허브 M터치 가 함께 예술촌으로 가꾸기 위해 2019년부터 몇차례 M터치 버스킹 거리공연 등을 통해 기초환경을 조성해온 영종도의 새로운 생활문화예술 지역이다. 인천시의회·인천중구청·인천공항공사 등에서 주민들이 제안한 예술촌 만들기 계획 에 공감하여 지원책을 실행해줌으로써 이곳의 밤거리가 밝아졌고 LED가로등 다수 설치 영종마로니에공원 내에 캐노피무대 기둥조명시설 조형물 및 잔디조성 작업을 지난 6월 완료함으로써 예술촌을 향한 기본 인프라를 갖추게 됐다. 너구리소굴 별난스페이스 활주로 등 공항마을에 오픈한 문화예술 카페들 사진 문병환 기자 또한 공항마을 내에는 너구리소굴 별난스페이스 활주로 등 특색 있는 음식점과 문화예술 카페 등이 하나씩 들어서면서 점차 예술촌의 모양새를 갖춰가고 있다. 4대 가요제를 통해 국내 최대 규모의 공연팀 풀 pool 을 갖추고 있는 M터치 회장 정현식·슈가버블 회장 한국프랜차이즈산업협회 회장 는 2019년 1월부터 본격적으로 한국의 관문이자 동북아 최대 규모의 복합리조트도시로 조성되고 있는 영종도를 중심으로 공익적 문화예술 나눔활동을 펼치고 있다.
#
# 요약 : 세월호사태 때는 전 한국민이 깊은 슬픔 에 이번 코로나사태 때는 전 세계인이 바이러스와의 전쟁 및 경제적 존망의 공포 속에서 불안한 나날을 보내고 있다. 운서역세권에 위치한 영종공항마을 H2 과 영종마로니에공원 영종하늘도시 9호공원 일대는 이곳 주민들과 공연 문화허브 M터치 가 함께 예술촌으로 가꾸기 위해 2019년부터 몇차례 M터치 버스킹 거리공연 등을 통해 기초환경을 조성해온 영종도의 새로운 생활문화예술 지역이다. 제를 통해 국내 최대 규모의 공연팀 풀 pool 을 갖추고 있는 M터치 회장 정현식·슈가버블 회장 한국프랜차이즈산업협회 회장 는 2019년 1월부터 본격적으로 한국의 관문이자 동북아 최대 규모의 복합리조트도시로 조성되고 있는 영종도를 중심으로 공익적 문화예술 나눔활동을 펼치고 있다.
